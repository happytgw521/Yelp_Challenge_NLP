# %%
import pymongo
import json
import pprint

# %%
myclient = pymongo.MongoClient("mongodb://localhost:27017/")
mydb = myclient["yelpdb"]

# %%
mydb.collection_names()
# Out:
# ['photo', 'user', 'business', 'review', 'tip', 'checkin']

# %% [markdown]
# Perform MongoDB query within one collection

# %%
# Top 10 Chinese / Japanese restaurants in Las Vegas with count of review > 500
myquery = {
    "categories": {"$regex": ".*Chinese.*|.*Japanese.*" },
    "city": "Las Vegas",
    "review_count": {"$gt": 500},
    "is_open":1
}

query_result = mydb['business'].find(myquery, {'name':1}).sort("stars",-1).limit(10)
for res in query_result:
    pprint.pprint(res)
# Out:
# {'_id': ObjectId('5c733b861d28450ce0420331'), 'name': 'Pan Asian'}
# {'_id': ObjectId('5c733b881d28450ce0421986'), 'name': 'Island Style Restaurant'}
# {'_id': ObjectId('5c733b8e1d28450ce0426356'),
#  'name': 'Kaizen Fusion Roll and Sushi'}
# {'_id': ObjectId('5c733b911d28450ce042825e'), 'name': 'Cafe Sanuki'}
# {'_id': ObjectId('5c733b931d28450ce042977d'),
#  'name': "Naked Fish's Sushi & Grill"}
# {'_id': ObjectId('5c733b951d28450ce042b05f'), 'name': 'Tonkatsu Kiyoshi'}
# {'_id': ObjectId('5c733b9a1d28450ce042f02c'), 'name': 'Shang Artisan Noodle'}
# {'_id': ObjectId('5c733b9a1d28450ce042f092'), 'name': 'Jjanga Steak & Sushi'}
# {'_id': ObjectId('5c733b9b1d28450ce042f6c4'),
#  'name': 'Soho Japanese Restaurant'}
# {'_id': ObjectId('5c733b9c1d28450ce04307ed'), 'name': 'Sweets Raku'}

# %%
# Count of review per city (Aggregate), sorted by counts
myaggregate = [{
    "$match": {'is_open':1}}, 
    {"$group": {'_id': '$city',
               'total': {'$sum': '$review_count'}}},
    {'$sort': {'total':-1}}]

aggregate_result = mydb['business'].aggregate(myaggregate)
for record in aggregate_result:
    print(record)
# Out:
# {'total': 1700331, '_id': 'Las Vegas'}
# {'total': 621906, '_id': 'Phoenix'}
# {'total': 422446, '_id': 'Toronto'}
# {'total': 317300, '_id': 'Scottsdale'}
# {'total': 265038, '_id': 'Charlotte'}
# {'total': 191609, '_id': 'Pittsburgh'}
# {'total': 185665, '_id': 'Henderson'}
# {'total': 168957, '_id': 'Tempe'}
# {'total': 145089, '_id': 'Mesa'}
# {'total': 131426, '_id': 'Montréal'}
# {'total': 130593, '_id': 'Chandler'}
# {'total': 111737, '_id': 'Gilbert'}
# {'total': 97702, '_id': 'Cleveland'}
# {'total': 87573, '_id': 'Madison'}
# {'total': 86010, '_id': 'Glendale'}
# {'total': 81757, '_id': 'Calgary'}
# {'total': 49620, '_id': 'Peoria'}
# {'total': 47542, '_id': 'Mississauga'}
# {'total': 43826, '_id': 'North Las Vegas'}
# {'total': 42425, '_id': 'Markham'}
# {'total': 29660, '_id': 'Surprise'}
# {'total': 25601, '_id': 'Goodyear'}
# {'total': 25216, '_id': 'Champaign'}
# {'total': 19877, '_id': 'Richmond Hill'}
# {'total': 19860, '_id': 'Avondale'}
# {'total': 16835, '_id': 'North York'}
# {'total': 16305, '_id': 'Concord'}
# {'total': 16033, '_id': 'Scarborough'}
# {'total': 15517, '_id': 'Lakewood'}
# {'total': 13740, '_id': 'Vaughan'}
# {'total': 13547, '_id': 'Huntersville'}
# {'total': 12643, '_id': 'Matthews'}
# {'total': 11145, '_id': 'Etobicoke'}
# {'total': 10698, '_id': 'Brampton'}
# {'total': 10467, '_id': 'Cave Creek'}
# {'total': 9929, '_id': 'Fort Mill'}
# {'total': 8193, '_id': 'Akron'}
# {'total': 8134, '_id': 'Boulder City'}
# {'total': 7882, '_id': 'Cornelius'}
# {'total': 7838, '_id': 'Westlake'}
# {'total': 7373, '_id': 'Thornhill'}
# {'total': 7161, '_id': 'Urbana'}
# {'total': 7033, '_id': 'Middleton'}
# {'total': 6886, '_id': 'Cleveland Heights'}
# {'total': 6392, '_id': 'Strongsville'}
# {'total': 6184, '_id': 'Gastonia'}
# {'total': 6153, '_id': 'Pineville'}
# {'total': 6087, '_id': 'Litchfield Park'}
# {'total': 5935, '_id': 'Fountain Hills'}
# {'total': 5922, '_id': 'Mentor'}
# {'total': 5844, '_id': 'Cuyahoga Falls'}
# {'total': 5774, '_id': 'Rocky River'}
# {'total': 5762, '_id': 'Monroeville'}
# {'total': 5752, '_id': 'North Olmsted'}
# {'total': 5210, '_id': 'Parma'}
# {'total': 4766, '_id': 'Beachwood'}
# {'total': 4459, '_id': 'Rock Hill'}
# {'total': 4438, '_id': 'Montreal'}
# {'total': 4381, '_id': 'Paradise Valley'}
# {'total': 4329, '_id': 'Aurora'}
# {'total': 4304, '_id': 'Kent'}
# {'total': 4299, '_id': 'Medina'}
# {'total': 3977, '_id': 'Oakville'}
# {'total': 3917, '_id': 'Independence'}
# {'total': 3835, '_id': 'Wexford'}
# {'total': 3828, '_id': 'Fitchburg'}
# {'total': 3646, '_id': 'Newmarket'}
# {'total': 3590, '_id': 'Solon'}
# {'total': 3545, '_id': 'Willoughby'}
# {'total': 3525, '_id': 'Indian Trail'}
# {'total': 3416, '_id': 'Avon'}
# {'total': 3405, '_id': 'Hudson'}
# {'total': 3325, '_id': 'Sun City'}
# {'total': 3316, '_id': 'Sun Prairie'}
# {'total': 3219, '_id': 'Homestead'}
# {'total': 3199, '_id': 'Pickering'}
# {'total': 3188, '_id': 'Laval'}
# {'total': 3163, '_id': 'Stow'}
# {'total': 3114, '_id': 'Belmont'}
# {'total': 3083, '_id': 'Bridgeville'}
# {'total': 3052, '_id': 'Davidson'}
# {'total': 2925, '_id': 'Woodmere'}
# {'total': 2905, '_id': 'Chagrin Falls'}
# {'total': 2832, '_id': 'Ajax'}
# {'total': 2814, '_id': 'Queen Creek'}
# {'total': 2769, '_id': 'Tolleson'}
# {'total': 2663, '_id': 'Laveen'}
# {'total': 2638, '_id': 'Woodbridge'}
# {'total': 2631, '_id': 'Coraopolis'}
# {'total': 2521, '_id': 'Bethel Park'}
# {'total': 2476, '_id': 'Whitby'}
# {'total': 2429, '_id': 'Lyndhurst'}
# {'total': 2382, '_id': 'Fairlawn'}
# {'total': 2334, '_id': 'Verona'}
# {'total': 2244, '_id': 'Carnegie'}
# {'total': 2241, '_id': 'Mayfield Heights'}
# {'total': 2203, '_id': 'Monona'}
# {'total': 2197, '_id': 'Canonsburg'}
# {'total': 2195, '_id': 'Waxhaw'}
# {'total': 2175, '_id': 'Fairview Park'}
# {'total': 2096, '_id': 'Twinsburg'}
# {'total': 2091, '_id': 'Middleburg Heights'}
# {'total': 1981, '_id': 'Berea'}
# {'total': 1945, '_id': 'Brunswick'}
# {'total': 1880, '_id': 'Elyria'}
# {'total': 1683, '_id': 'Sewickley'}
# {'total': 1681, '_id': 'Streetsboro'}
# {'total': 1654, '_id': 'Avon Lake'}
# {'total': 1645, '_id': 'El Mirage'}
# {'total': 1603, '_id': 'Unionville'}
# {'total': 1593, '_id': 'Brossard'}
# {'total': 1580, '_id': 'Verdun'}
# {'total': 1554, '_id': 'LAS VEGAS'}
# {'total': 1543, '_id': 'East York'}
# {'total': 1522, '_id': 'Harrisburg'}
# {'total': 1513, '_id': 'North Royalton'}
# {'total': 1494, '_id': 'Monroe'}
# {'total': 1490, '_id': 'Buckeye'}
# {'total': 1474, '_id': 'Brooklyn'}
# {'total': 1462, '_id': 'Spring Valley'}
# {'total': 1460, '_id': 'West Mifflin'}
# {'total': 1441, '_id': 'Denver'}
# {'total': 1433, '_id': 'Mint Hill'}
# {'total': 1429, '_id': 'Painesville'}
# {'total': 1416, '_id': 'Murrysville'}
# {'total': 1387, '_id': 'Macedonia'}
# {'total': 1380, '_id': 'Carefree'}
# {'total': 1373, '_id': 'Broadview Heights'}
# {'total': 1351, '_id': 'Dorval'}
# {'total': 1208, '_id': 'Saint-Laurent'}
# {'total': 1197, '_id': 'Amherst'}
# {'total': 1180, '_id': 'McMurray'}
# {'total': 1173, '_id': 'Sun City West'}
# {'total': 1168, '_id': 'Northfield'}
# {'total': 1167, '_id': 'Stoughton'}
# {'total': 1159, '_id': 'Brecksville'}
# {'total': 1123, '_id': 'Valley View'}
# {'total': 1114, '_id': 'York'}
# {'total': 1110, '_id': 'Bedford'}
# {'total': 1097, '_id': 'Gibsonia'}
# {'total': 1082, '_id': 'Indian Land'}
# {'total': 1066, '_id': 'Airdrie'}
# {'total': 1045, '_id': 'Oakmont'}
# {'total': 1039, '_id': 'Dollard-des-Ormeaux'}
# {'total': 1036, '_id': 'South Euclid'}
# {'total': 1033, '_id': 'Moon Township'}
# {'total': 1024, '_id': 'Chesterland'}
# {'total': 1000, '_id': 'Allison Park'}
# {'total': 986, '_id': 'Ahwatukee'}
# {'total': 962, '_id': 'Savoy'}
# {'total': 956, '_id': 'University Heights'}
# {'total': 953, '_id': 'Pointe-Claire'}
# {'total': 941, '_id': 'Euclid'}
# {'total': 927, '_id': 'Kannapolis'}
# {'total': 919, '_id': 'North Ridgeville'}
# {'total': 917, '_id': 'Lorain'}
# {'total': 900, '_id': 'West Homestead'}
# {'total': 895, '_id': 'Westmount'}
# {'total': 861, '_id': 'Warrensville Heights'}
# {'total': 852, '_id': 'Chardon'}
# {'total': 834, '_id': 'Youngtown'}
# {'total': 829, '_id': 'Olmsted Falls'}
# {'total': 822, '_id': 'Waunakee'}
# {'total': 811, '_id': 'New Kensington'}
# {'total': 794, '_id': 'Lake Wylie'}
# {'total': 788, '_id': 'Highland Heights'}
# {'total': 767, '_id': 'Parma Heights'}
# {'total': 764, '_id': 'Peninsula'}
# {'total': 758, '_id': 'Orange Village'}
# {'total': 750, '_id': 'Tega Cay'}
# {'total': 728, '_id': 'Seven Hills'}
# {'total': 720, '_id': 'Irwin'}
# {'total': 720, '_id': 'South Las Vegas'}
# {'total': 701, '_id': 'Wickliffe'}
# {'total': 700, '_id': 'Anthem'}
# {'total': 695, '_id': 'McKees Rocks'}
# {'total': 690, '_id': 'Mount Holly'}
# {'total': 677, '_id': 'Mount Horeb'}
# {'total': 676, '_id': 'Willoughby Hills'}
# {'total': 671, '_id': 'Clover'}
# {'total': 668, '_id': 'Oregon'}
# {'total': 662, '_id': 'Eastlake'}
# {'total': 661, '_id': 'Maple'}
# {'total': 653, '_id': 'Brook Park'}
# {'total': 639, '_id': 'Willowick'}
# {'total': 617, '_id': 'Glenshaw'}
# {'total': 615, '_id': 'Bellevue'}
# {'total': 606, '_id': 'Tarentum'}
# {'total': 592, '_id': 'Blue Diamond'}
# {'total': 571, '_id': 'Stouffville'}
# {'total': 562, '_id': 'Higley'}
# {'total': 560, '_id': 'Shaker Heights'}
# {'total': 559, '_id': 'Whitchurch-Stouffville'}
# {'total': 558, '_id': 'Pleasant Hills'}
# {'total': 545, '_id': 'Bay Village'}
# {'total': 528, '_id': 'N. Las Vegas'}
# {'total': 527, '_id': 'Richfield'}
# {'total': 522, '_id': 'Tallmadge'}
# {'total': 519, '_id': 'Robinson Township'}
# {'total': 503, '_id': 'Lasalle'}
# {'total': 500, '_id': 'Outremont'}
# {'total': 485, '_id': 'Mooresville'}
# {'total': 483, '_id': 'Missisauga'}
# {'total': 472, '_id': 'Stallings'}
# {'total': 467, '_id': 'Wesley Chapel'}
# {'total': 465, '_id': 'North Versailles'}
# {'total': 458, '_id': 'Longueuil'}
# {'total': 457, '_id': 'HENDERSON'}
# {'total': 438, '_id': 'Las  Vegas'}
# {'total': 437, '_id': 'Guadalupe'}
# {'total': 434, '_id': 'DeForest'}
# {'total': 419, '_id': 'McKeesport'}
# {'total': 417, '_id': 'Lachine'}
# {'total': 414, '_id': 'Pepper Pike'}
# {'total': 412, '_id': 'Oakdale'}
# {'total': 405, '_id': 'North Huntingdon'}
# {'total': 396, '_id': 'Braddock'}
# {'total': 395, '_id': 'Burton'}
# {'total': 394, '_id': 'N Las Vegas'}
# {'total': 386, '_id': 'Mayfield'}
# {'total': 385, '_id': 'Cottage Grove'}
# {'total': 384, '_id': 'Mt. Lebanon'}
# {'total': 384, '_id': 'Richmond Heights'}
# {'total': 383, '_id': 'Pierrefonds'}
# {'total': 380, '_id': 'Saint-Sauveur'}
# {'total': 379, '_id': 'Mahomet'}
# {'total': 371, '_id': 'Garfield Heights'}
# {'total': 364, '_id': 'Mc Kees Rocks'}
# {'total': 357, '_id': 'Wadsworth'}
# {'total': 351, '_id': 'Cross Plains'}
# {'total': 350, '_id': 'Apache Junction'}
# {'total': 344, '_id': 'Sun Lakes'}
# {'total': 339, '_id': 'Copley'}
# {'total': 339, '_id': 'White Oak'}
# {'total': 337, '_id': 'Fort McDowell'}
# {'total': 335, '_id': 'Ambridge'}
# {'total': 334, '_id': 'Kirkland'}
# {'total': 323, '_id': 'MESA'}
# {'total': 322, '_id': 'Munhall'}
# {'total': 317, '_id': 'Sheffield Village'}
# {'total': 315, '_id': 'Blakeney'}
# {'total': 313, '_id': 'Kirtland'}
# {'total': 312, '_id': 'Rantoul'}
# {'total': 309, '_id': 'Lower Lawrenceville'}
# {'total': 304, '_id': 'Vaudreuil-Dorion'}
# {'total': 304, '_id': 'Moreland Hills'}
# {'total': 303, '_id': 'Halton Hills'}
# {'total': 298, '_id': 'Enterprise'}
# {'total': 296, '_id': 'Mayfield Village'}
# {'total': 294, '_id': 'Tremont'}
# {'total': 294, '_id': 'Upper St Clair'}
# {'total': 292, '_id': 'Woodmere Village'}
# {'total': 290, '_id': 'McFarland'}
# {'total': 285, '_id': 'Scottdale'}
# {'total': 283, '_id': 'Millvale'}
# {'total': 280, '_id': 'Middlefield'}
# {'total': 277, '_id': 'Georgetown'}
# {'total': 275, '_id': 'Cecil'}
# {'total': 271, '_id': 'Mount Lebanon'}
# {'total': 270, '_id': 'Cramerton'}
# {'total': 268, '_id': 'Springdale'}
# {'total': 268, '_id': 'Maple Heights'}
# {'total': 267, '_id': 'Paradise'}
# {'total': 263, '_id': 'Monticello'}
# {'total': 263, '_id': 'Bolton'}
# {'total': 262, '_id': 'Ross Township'}
# {'total': 261, '_id': 'Elizabeth'}
# {'total': 259, '_id': 'Windsor'}
# {'total': 257, '_id': 'Orange'}
# {'total': 257, '_id': 'Grand River'}
# {'total': 255, '_id': 'Munroe Falls'}
# {'total': 255, '_id': 'De Forest'}
# {'total': 255, '_id': 'Bedford Heights'}
# {'total': 254, '_id': 'Rocky View'}
# {'total': 254, '_id': 'North Randall'}
# {'total': 252, '_id': 'LasVegas'}
# {'total': 252, '_id': 'West View'}
# {'total': 248, '_id': 'Las vegas'}
# {'total': 244, '_id': 'Robinson'}
# {'total': 240, '_id': 'East Gwillimbury'}
# {'total': 239, '_id': 'Summerlin'}
# {'total': 237, '_id': 'King City'}
# {'total': 235, '_id': 'Concord Mills'}
# {'total': 234, '_id': 'Heidelberg'}
# {'total': 234, '_id': 'Laveen Village'}
# {'total': 234, '_id': 'Clark'}
# {'total': 232, '_id': 'Turtle Creek'}
# {'total': 229, '_id': 'Valley City'}
# {'total': 229, '_id': 'Bradford'}
# {'total': 228, '_id': 'Mont-Royal'}
# {'total': 222, '_id': 'Lowell'}
# {'total': 221, '_id': 'Caledon'}
# {'total': 215, '_id': 'Aspinwall'}
# {'total': 212, '_id': 'Brentwood'}
# {'total': 212, '_id': 'Mc Farland'}
# {'total': 212, '_id': 'Mentor-on-the-Lake'}
# {'total': 210, '_id': 'Sharpsburg'}
# {'total': 201, '_id': 'Upper Saint Clair'}
# {'total': 201, '_id': 'Leetsdale'}
# {'total': 200, '_id': 'Crafton'}
# {'total': 200, '_id': 'Newbury'}
# {'total': 198, '_id': 'Grafton'}
# {'total': 198, '_id': 'Rexdale'}
# {'total': 197, '_id': 'Penn Hills'}
# {'total': 197, '_id': "L'Île-Perrot"}
# {'total': 193, '_id': 'TEMPE'}
# {'total': 193, '_id': 'Belleville'}
# {'total': 189, '_id': 'Columbia Station'}
# {'total': 186, '_id': 'Finleyville'}
# {'total': 183, '_id': 'Dallas'}
# {'total': 178, '_id': 'Boucherville'}
# {'total': 178, '_id': 'Brookpark'}
# {'total': 178, '_id': 'Trafford'}
# {'total': 175, '_id': 'Etna'}
# {'total': 173, '_id': 'Clairton'}
# {'total': 172, '_id': 'Norton'}
# {'total': 168, '_id': 'Imperial'}
# {'total': 166, '_id': 'Bradford West Gwillimbury'}
# {'total': 166, '_id': 'Fairport Harbor'}
# {'total': 156, '_id': 'Nellis AFB'}
# {'total': 155, '_id': 'Sainte-Anne-de-Bellevue'}
# {'total': 154, '_id': 'Tornto'}
# {'total': 153, '_id': 'CHARLOTTE'}
# {'total': 153, '_id': 'Hampton Township'}
# {'total': 152, '_id': 'Cheswick'}
# {'total': 152, '_id': 'Greenfield Park'}
# {'total': 151, '_id': 'Dollard-Des-Ormeaux'}
# {'total': 151, '_id': 'Saint-Jean-sur-Richelieu'}
# {'total': 147, '_id': 'Locust'}
# {'total': 144, '_id': 'Saint-Lambert'}
# {'total': 143, '_id': 'Hinckley'}
# {'total': 141, '_id': 'McCandless Township'}
# {'total': 140, '_id': 'Midland'}
# {'total': 139, '_id': 'Anjou'}
# {'total': 137, '_id': 'charlotte'}
# {'total': 137, '_id': 'La Prairie'}
# {'total': 136, '_id': 'Saint-Hubert'}
# {'total': 136, '_id': 'Moon'}
# {'total': 134, '_id': 'las vegas'}
# {'total': 133, '_id': 'Waddell'}
# {'total': 133, '_id': 'Stanley'}
# {'total': 132, '_id': 'Chestermere'}
# {'total': 130, '_id': 'South Park Township'}
# {'total': 130, '_id': 'Wilkinsburg'}
# {'total': 129, '_id': 'Mt Lebanon'}
# {'total': 128, '_id': 'Saint-Leonard'}
# {'total': 127, '_id': 'Don Mills'}
# {'total': 123, '_id': 'Mc Murray'}
# {'total': 120, '_id': 'Montrose'}
# {'total': 119, '_id': 'Gates Mills'}
# {'total': 119, '_id': 'GILBERT'}
# {'total': 118, '_id': 'Weddington'}
# {'total': 118, '_id': 'Plum'}
# {'total': 117, '_id': 'Port Credit'}
# {'total': 114, '_id': 'Castle Shannon'}
# {'total': 114, '_id': 'Robinson Twp.'}
# {'total': 112, '_id': 'Monongahela'}
# {'total': 111, '_id': 'Lawrenceville'}
# {'total': 110, '_id': 'South Park'}
# {'total': 110, '_id': 'Emsworth'}
# {'total': 108, '_id': 'Saint-Léonard'}
# {'total': 108, '_id': 'Glendale Az'}
# {'total': 106, '_id': 'Mckees Rocks'}
# {'total': 106, '_id': 'LaSalle'}
# {'total': 104, '_id': 'Harrison City'}
# {'total': 103, '_id': 'Downtown'}
# {'total': 101, '_id': 'Charlotte '}
# {'total': 101, '_id': 'lyndhurst'}
# {'total': 99, '_id': 'W Henderson'}
# {'total': 99, '_id': 'Ravenna'}
# {'total': 98, '_id': 'Montral'}
# {'total': 98, '_id': 'Kleinburg'}
# {'total': 98, '_id': 'Green Tree'}
# {'total': 96, '_id': 'Oakland'}
# {'total': 96, '_id': 'Lower Burrell'}
# {'total': 96, '_id': 'Saint-Jérôme'}
# {'total': 96, '_id': 'Sheffield'}
# {'total': 95, '_id': 'Pittsburg'}
# {'total': 94, '_id': 'Walton Hills'}
# {'total': 93, '_id': 'Chambly'}
# {'total': 92, '_id': 'Saint Joseph'}
# {'total': 91, '_id': 'SCOTTSDALE'}
# {'total': 91, '_id': 'Boisbriand'}
# {'total': 90, '_id': 'Brooklin'}
# {'total': 90, '_id': 'Saint-Eustache'}
# {'total': 89, '_id': 'Las Vegas '}
# {'total': 89, '_id': 'Brookline'}
# {'total': 88, '_id': 'Presto'}
# {'total': 86, '_id': 'Swissvale'}
# {'total': 83, '_id': 'phoenix'}
# {'total': 83, '_id': 'Jefferson Hills'}
# {'total': 82, '_id': 'NORTH LAS VEGAS'}
# {'total': 82, '_id': 'Upper St. Clair'}
# {'total': 81, '_id': 'Dravosburg'}
# {'total': 80, '_id': 'Rosemère'}
# {'total': 80, '_id': 'Las Vegas & Henderson'}
# {'total': 79, '_id': 'Shadyside'}
# {'total': 77, '_id': 'Champlain'}
# {'total': 76, '_id': 'McAdenville'}
# {'total': 76, '_id': 'Wilmerding'}
# {'total': 75, '_id': 'Milton'}
# {'total': 74, '_id': 'N W Las Vegas'}
# {'total': 74, '_id': 'Etibicoke'}
# {'total': 74, '_id': 'Peters Township'}
# {'total': 74, '_id': 'N Ridgeville'}
# {'total': 74, '_id': 'Terrebonne'}
# {'total': 73, '_id': 'St-Benoît de Mirabel'}
# {'total': 73, '_id': 'W Spring Valley'}
# {'total': 72, '_id': 'Sauk City'}
# {'total': 70, '_id': 'Sheffield Lake'}
# {'total': 70, '_id': 'McCandless'}
# {'total': 70, '_id': 'Olmsted Township'}
# {'total': 70, '_id': 'Mcmurray'}
# {'total': 69, '_id': 'Montréal-Ouest'}
# {'total': 68, '_id': 'Rouses Point'}
# {'total': 67, '_id': 'Henderston'}
# {'total': 67, '_id': 'Mint  Hill'}
# {'total': 67, '_id': 'PHOENIX'}
# {'total': 66, '_id': 'Black Earth'}
# {'total': 66, '_id': 'Bath'}
# {'total': 66, '_id': 'Nobleton'}
# {'total': 66, '_id': 'Sagamore Hills'}
# {'total': 65, '_id': 'Centennial Hills'}
# {'total': 65, '_id': 'Mantua'}
# {'total': 65, '_id': 'Sainte-Julie'}
# {'total': 65, '_id': 'Beaconsfield'}
# {'total': 64, '_id': 'Vegas'}
# {'total': 64, '_id': 'SURPRISE'}
# {'total': 63, '_id': 'MADISON'}
# {'total': 63, '_id': 'West Montréal'}
# {'total': 62, '_id': 'North Olmstead'}
# {'total': 62, '_id': 'Middleburg Hts'}
# {'total': 61, '_id': 'Oakwood Village'}
# {'total': 61, '_id': 'Uxbridge'}
# {'total': 61, '_id': 'Rocky View County'}
# {'total': 60, '_id': 'East Liberty'}
# {'total': 60, '_id': 'Mc Donald'}
# {'total': 59, '_id': 'Avalon'}
# {'total': 59, '_id': 'Wilkins Township'}
# {'total': 59, '_id': 'Harmarville'}
# {'total': 59, '_id': 'Sainte-Adèle'}
# {'total': 58, '_id': 'Gormley'}
# {'total': 58, '_id': 'Litchfield'}
# {'total': 58, '_id': 'Fort Mcdowell'}
# {'total': 57, '_id': 'Vimont'}
# {'total': 57, '_id': 'Dormont'}
# {'total': 57, '_id': 'Deforest'}
# {'total': 57, '_id': 'boulder city'}
# {'total': 57, '_id': 'Dollard-des Ormeaux'}
# {'total': 56, '_id': 'scottsdale'}
# {'total': 56, '_id': 'Châteauguay'}
# {'total': 55, '_id': 'Mcfarland'}
# {'total': 55, '_id': 'Bainbridge'}
# {'total': 55, '_id': 'Montreal-Nord'}
# {'total': 53, '_id': 'Paoli'}
# {'total': 53, '_id': 'Medina Township'}
# {'total': 53, '_id': 'Mentor On The Lake'}
# {'total': 53, '_id': 'Blawnox'}
# {'total': 53, '_id': 'Sainte-Anne-De-Bellevue'}
# {'total': 53, '_id': 'Ben Avon'}
# {'total': 52, '_id': 'Baldwin'}
# {'total': 52, '_id': 'Library'}
# {'total': 51, '_id': 'Russellton'}
# {'total': 51, '_id': 'RIchmond Hill'}
# {'total': 51, '_id': 'Saint-Lazare'}
# {'total': 50, '_id': 'Schaumburg'}
# {'total': 50, '_id': 'Mirabel'}
# {'total': 50, '_id': 'Blainville'}
# {'total': 49, '_id': 'La Salle'}
# {'total': 49, '_id': 'Export'}
# {'total': 49, '_id': 'St Joseph'}
# {'total': 48, '_id': 'York Regional Municipality'}
# {'total': 48, '_id': 'Tuscola'}
# {'total': 48, '_id': 'Arnold'}
# {'total': 48, '_id': 'East McKeesport'}
# {'total': 47, '_id': 'Saint-Hyacinthe'}
# {'total': 47, '_id': 'henderson'}
# {'total': 47, '_id': 'Sainte-Thérèse'}
# {'total': 47, '_id': 'Harrisbug'}
# {'total': 46, '_id': 'C Las Vegas'}
# {'total': 45, '_id': 'Lower burrell'}
# {'total': 45, '_id': 'GOODYEAR'}
# {'total': 45, '_id': 'Île des Soeurs'}
# {'total': 45, '_id': 'Beloeil'}
# {'total': 45, '_id': 'Squirrel Hill'}
# {'total': 44, '_id': 'Oakwood'}
# {'total': 43, '_id': 'Neville Island'}
# {'total': 43, '_id': 'McDonald'}
# {'total': 43, '_id': 'Balzac'}
# {'total': 43, '_id': 'Warrensville Hts.'}
# {'total': 43, '_id': 'Ogden'}
# {'total': 43, '_id': 'Hiram'}
# {'total': 42, '_id': 'Elizabeth Township'}
# {'total': 42, '_id': 'Sunrise'}
# {'total': 42, '_id': 'Willowdale'}
# {'total': 42, '_id': 'mesa'}
# {'total': 41, '_id': 'Waterloo'}
# {'total': 41, '_id': 'Mont-Saint-Hilaire'}
# {'total': 41, '_id': 'Delson'}
# {'total': 41, '_id': 'Dollard-Des Ormeaux'}
# {'total': 40, '_id': 'Central Henderson'}
# {'total': 39, '_id': 'Henderson (Green Valley)'}
# {'total': 39, '_id': 'Mentor On the'}
# {'total': 39, '_id': 'Caledon East'}
# {'total': 39, '_id': 'King'}
# {'total': 38, '_id': 'PEORIA'}
# {'total': 38, '_id': 'Rigaud'}
# {'total': 38, '_id': 'Dane'}
# {'total': 38, '_id': 'Saint-Jerome'}
# {'total': 38, '_id': 'Sainte-Adele'}
# {'total': 38, '_id': 'Lowesville'}
# {'total': 38, '_id': 'South Charlotte'}
# {'total': 37, '_id': 'Ranlo'}
# {'total': 37, '_id': 'Phoenix, AZ'}
# {'total': 37, '_id': 'Schomberg'}
# {'total': 37, '_id': 'Saint-Bernard-de-Lacolle'}
# {'total': 37, '_id': 'Rio Verde'}
# {'total': 36, '_id': 'Toronto Division'}
# {'total': 36, '_id': 'Saint-Constant'}
# {'total': 36, '_id': 'Glassport'}
# {'total': 36, '_id': 'Lagrange'}
# {'total': 35, '_id': 'Las Vegas East'}
# {'total': 35, '_id': 'East Ajax'}
# {'total': 35, '_id': 'Herminie'}
# {'total': 35, '_id': 'GIlbert'}
# {'total': 35, '_id': 'Midnapore'}
# {'total': 35, '_id': 'Forest Hills'}
# {'total': 35, '_id': 'NELLIS AFB'}
# {'total': 35, '_id': 'San Diego'}
# {'total': 34, '_id': 'North Hills'}
# {'total': 34, '_id': 'Broadview Hts'}
# {'total': 34, '_id': 'LAVEEN'}
# {'total': 34, '_id': 'Lachute'}
# {'total': 34, '_id': 'Indian land'}
# {'total': 33, '_id': 'Saint-Henri'}
# {'total': 33, '_id': 'Columbus'}
# {'total': 33, '_id': 'Chateauguay'}
# {'total': 32, '_id': 'North Toronto'}
# {'total': 32, '_id': 'St-Jerome'}
# {'total': 32, '_id': 'Montréal-Nord'}
# {'total': 32, '_id': 'Wildwood'}
# {'total': 31, '_id': 'Mont-Saint-Grégoire'}
# {'total': 31, '_id': 'Mount Albert'}
# {'total': 30, '_id': 'Kennedy Township'}
# {'total': 30, '_id': 'MONROEVILLE'}
# {'total': 30, '_id': 'Shaler Township'}
# {'total': 30, '_id': 'Goodwood'}
# {'total': 29, '_id': 'INDIAN LAND'}
# {'total': 29, '_id': 'Downsview'}
# {'total': 29, '_id': 'East Cleveland'}
# {'total': 29, '_id': 'Philo'}
# {'total': 29, '_id': 'Richmonhill'}
# {'total': 29, '_id': "L'ile-Perrot"}
# {'total': 29, '_id': 'Morgan Hill'}
# {'total': 29, '_id': 'Bellvue'}
# {'total': 29, '_id': 'Mascouche'}
# {'total': 28, '_id': 'Montrèal'}
# {'total': 28, '_id': 'Shorewood Hills'}
# {'total': 28, '_id': 'Brunswick Hills'}
# {'total': 28, '_id': 'Richmond Hts'}
# {'total': 28, '_id': 'New Eagle'}
# {'total': 27, '_id': 'Montreal-West'}
# {'total': 27, '_id': 'Oka'}
# {'total': 27, '_id': 'Elrama'}
# {'total': 27, '_id': 'cave creek'}
# {'total': 27, '_id': 'East Pittsburgh'}
# {'total': 27, '_id': 'Cleveland Hghts.'}
# {'total': 27, '_id': 'St-Leonard'}
# {'total': 27, '_id': 'Sidney'}
# {'total': 26, '_id': 'Mcknight'}
# {'total': 26, '_id': 'Mount Washington'}
# {'total': 26, '_id': 'Edgewood'}
# {'total': 26, '_id': 'Concord Township'}
# {'total': 26, '_id': 'Bainbridge Township'}
# {'total': 26, '_id': 'Saint-Sauveur-des-Monts'}
# {'total': 26, '_id': 'Mayfield Heights (Cleveland)'}
# {'total': 26, '_id': 'Rosemere'}
# {'total': 26, '_id': 'Duquesne'}
# {'total': 26, '_id': 'Kahnawake'}
# {'total': 26, '_id': 'Belle Vernon'}
# {'total': 26, '_id': 'Boston Heights'}
# {'total': 25, '_id': 'Scarobrough'}
# {'total': 25, '_id': 'Central'}
# {'total': 25, '_id': 'Marshall'}
# {'total': 25, '_id': 'Mckeesport'}
# {'total': 25, '_id': 'Erie'}
# {'total': 25, '_id': 'Central City Village'}
# {'total': 25, '_id': 'Northwest Calgary'}
# {'total': 25, '_id': 'N. Olmsted'}
# {'total': 25, '_id': 'Monoroeville'}
# {'total': 25, '_id': 'Homer'}
# {'total': 24, '_id': 'Morin-Heights'}
# {'total': 24, '_id': 'New River'}
# {'total': 24, '_id': 'City Center'}
# {'total': 24, '_id': 'Joliette'}
# {'total': 24, '_id': 'Auburn Township'}
# {'total': 24, '_id': 'East Mc Keesport'}
# {'total': 23, '_id': 'Le Sud-Ouest'}
# {'total': 23, '_id': 'McKeesRocks'}
# {'total': 23, '_id': 'North of Brampton'}
# {'total': 23, '_id': 'Cote Saint-Luc'}
# {'total': 23, '_id': 'Downtown Toronto'}
# {'total': 23, '_id': 'Rocky View No. 44'}
# {'total': 23, '_id': 'Sainte-Genevieve'}
# {'total': 23, '_id': 'Oberlin'}
# {'total': 22, '_id': 'Rostraver'}
# {'total': 22, '_id': 'Phx'}
# {'total': 22, '_id': 'Mentor On the Lake'}
# {'total': 22, '_id': 'Promenade'}
# {'total': 22, '_id': 'FORT MILL'}
# {'total': 22, '_id': 'Cuyahoga Heights'}
# {'total': 22, '_id': 'Piedmont'}
# {'total': 22, '_id': 'Saint-Bruno-de-Montarville'}
# {'total': 22, '_id': "L'Île-Bizard"}
# {'total': 22, '_id': 'Thornhil'}
# {'total': 22, '_id': 'Perry'}
# {'total': 22, '_id': 'Bedford Hts'}
# {'total': 21, '_id': 'Queen creek'}
# {'total': 21, '_id': 'toronto'}
# {'total': 21, '_id': 'San Tan Valley'}
# {'total': 21, '_id': 'Montreal-Ouest'}
# {'total': 21, '_id': 'St-Bruno-de-Montarville'}
# {'total': 21, '_id': 'Durham Regional Municipality'}
# {'total': 21, '_id': 'Urbana, Illinois'}
# {'total': 21, '_id': 'Grand Canyon'}
# {'total': 21, '_id': 'Communauté-Urbaine-de-Montréal'}
# {'total': 21, '_id': 'North Huntington'}
# {'total': 21, '_id': 'Tottenham'}
# {'total': 21, '_id': 'N E Las Vegas'}
# {'total': 21, '_id': 'Pointe-Aux-Trembles'}
# {'total': 20, '_id': 'Clarkson'}
# {'total': 20, '_id': 'Lufkin'}
# {'total': 20, '_id': 'Ste-Rose'}
# {'total': 20, '_id': 'Venetia'}
# {'total': 20, '_id': 'LaGrange'}
# {'total': 20, '_id': 'CONCORD'}
# {'total': 20, '_id': 'Nellis Air Force Base'}
# {'total': 20, '_id': 'Geauga'}
# {'total': 19, '_id': 'Repentigny'}
# {'total': 19, '_id': 'East Mississauga'}
# {'total': 19, '_id': 'Novelty'}
# {'total': 19, '_id': 'Beeton'}
# {'total': 19, '_id': 'moon'}
# {'total': 19, '_id': '\u200bChandler'}
# {'total': 18, '_id': "Notre-Dame-de-l'Ile-Perrot"}
# {'total': 18, '_id': 'Whiitby'}
# {'total': 18, '_id': 'Troy Township'}
# {'total': 18, '_id': 'Saint-Bruno'}
# {'total': 18, '_id': 'TORONTO'}
# {'total': 18, '_id': 'Lakewood, Oh'}
# {'total': 18, '_id': 'Scottsdale, AZ'}
# {'total': 18, '_id': 'Estérel'}
# {'total': 18, '_id': 'Franklin Park'}
# {'total': 18, '_id': 'Shaker Hts'}
# {'total': 18, '_id': 'Creighton'}
# {'total': 17, '_id': 'Moon TWP'}
# {'total': 17, '_id': 'Hendersonville'}
# {'total': 17, '_id': 'Fort mill'}
# {'total': 17, '_id': 'Ahwahtukee'}
# {'total': 17, '_id': 'Temecula'}
# {'total': 17, '_id': 'Sainte-Catherine'}
# {'total': 17, '_id': 'Pointe Claire'}
# {'total': 17, '_id': 'Holland Landing'}
# {'total': 17, '_id': 'Warrensville Hts'}
# {'total': 17, '_id': 'Pine'}
# {'total': 17, '_id': 'Cleveland Heigh'}
# {'total': 17, '_id': 'Bratenahl'}
# {'total': 17, '_id': 'Warrensville'}
# {'total': 17, '_id': 'Glen Williams'}
# {'total': 17, '_id': 'Mt Holly'}
# {'total': 17, '_id': 'New York'}
# {'total': 17, '_id': 'Ballantyne'}
# {'total': 17, '_id': 'University Ht'}
# {'total': 17, '_id': 'University Hts '}
# {'total': 16, '_id': 'Chargrin Falls'}
# {'total': 16, '_id': 'Brooklyn Heights'}
# {'total': 16, '_id': 'Highland Hills'}
# {'total': 16, '_id': 'Rural Ridge'}
# {'total': 16, '_id': 'Northfield Center Township'}
# {'total': 16, '_id': 'Cuddy'}
# {'total': 16, '_id': 'Lawrence'}
# {'total': 16, '_id': 'Moon Twp'}
# {'total': 16, '_id': 'Barberton'}
# {'total': 16, '_id': 'Nellis Afb'}
# {'total': 16, '_id': 'Mesa AZ'}
# {'total': 15, '_id': 'MACEDONIA'}
# {'total': 15, '_id': 'Red Mountain'}
# {'total': 15, '_id': 'tempe'}
# {'total': 15, '_id': 'East Mesa'}
# {'total': 15, '_id': 'Sainte-Anne-des-Plaines'}
# {'total': 15, '_id': 'Rawdon'}
# {'total': 15, '_id': 'AVON'}
# {'total': 15, '_id': 'Las Vegas Nv'}
# {'total': 15, '_id': 'GASTONIA'}
# {'total': 15, '_id': 'Pitcairn'}
# {'total': 15, '_id': 'Median'}
# {'total': 15, '_id': 'Saint Laurent'}
# {'total': 15, '_id': 'Ashburn'}
# {'total': 15, '_id': 'Las Vegas, NV'}
# {'total': 15, '_id': 'Saint-Philippe'}
# {'total': 15, '_id': 'Mathews'}
# {'total': 15, '_id': 'Saint-Marc-sur-Richelieu'}
# {'total': 14, '_id': 'Hyland Heights'}
# {'total': 14, '_id': 'Cooksville'}
# {'total': 14, '_id': 'Eighty Four'}
# {'total': 14, '_id': 'Etobiicoke'}
# {'total': 14, '_id': 'North Strabane Township'}
# {'total': 14, '_id': 'North Charlotte'}
# {'total': 14, '_id': 'Harrisburg,'}
# {'total': 14, '_id': 'Yorkville'}
# {'total': 14, '_id': 'Phoenix '}
# {'total': 14, '_id': 'Mt. Holly'}
# {'total': 14, '_id': 'River Drive Park'}
# {'total': 14, '_id': 'Phoenx'}
# {'total': 14, '_id': 'Russell Twp'}
# {'total': 13, '_id': 'Arrowhead'}
# {'total': 13, '_id': 'Sunnyslope'}
# {'total': 13, '_id': 'Ville Mont-Royal'}
# {'total': 13, '_id': 'St Leonard'}
# {'total': 13, '_id': 'Marvin'}
# {'total': 13, '_id': 'Cranberry Twp'}
# {'total': 13, '_id': 'Thorncliffe Park'}
# {'total': 13, '_id': 'Mercier'}
# {'total': 13, '_id': 'Salaberry-De-Valleyfield'}
# {'total': 13, '_id': 'Hendserson'}
# {'total': 13, '_id': 'surprise'}
# {'total': 13, '_id': 'North Scottsdale'}
# {'total': 13, '_id': 'South Amherst'}
# {'total': 13, '_id': 'Middleburg Hts.'}
# {'total': 13, '_id': 'Deerfield'}
# {'total': 12, '_id': 'Roxboro'}
# {'total': 12, '_id': 'Fabreville'}
# {'total': 12, '_id': 'N. Randall'}
# {'total': 12, '_id': 'Cuyahoga Fls'}
# {'total': 12, '_id': 'Rillton'}
# {'total': 12, '_id': 'Clinton'}
# {'total': 12, '_id': 'South Hills'}
# {'total': 12, '_id': 'Oak Ridges'}
# {'total': 12, '_id': 'glendale'}
# {'total': 12, '_id': 'Salaberry-de-Valleyfield'}
# {'total': 12, '_id': 'Phoenix,'}
# {'total': 12, '_id': 'Montgomery'}
# {'total': 12, '_id': 'Black Rock City'}
# {'total': 12, '_id': 'Mt. Horeb'}
# {'total': 12, '_id': 'PARMA HEIGHTS'}
# {'total': 11, '_id': 'Ross'}
# {'total': 11, '_id': 'Central City'}
# {'total': 11, '_id': 'Scottadale'}
# {'total': 11, '_id': 'Summerlin South'}
# {'total': 11, '_id': 'Los Angeles'}
# {'total': 11, '_id': 'Indianola'}
# {'total': 11, '_id': 'Ahwatukee Foothills Village'}
# {'total': 11, '_id': 'Northfield Center'}
# {'total': 11, '_id': 'Ft. Mill'}
# {'total': 11, '_id': 'Saint-Jean-Sur-Richelieu'}
# {'total': 11, '_id': 'Antioch'}
# {'total': 11, '_id': 'Pincourt'}
# {'total': 11, '_id': 'Southeast Calgary'}
# {'total': 11, '_id': 'Pittsburgh '}
# {'total': 11, '_id': 'Saint-Hippolyte'}
# {'total': 11, '_id': 'Mississuaga'}
# {'total': 11, '_id': 'Québec'}
# {'total': 11, '_id': 'Ville Saint Laurent'}
# {'total': 10, '_id': 'Rankin'}
# {'total': 10, '_id': 'Auburn Twp'}
# {'total': 10, '_id': 'Côte Saint-Luc'}
# {'total': 10, '_id': 'Berry'}
# {'total': 10, '_id': 'East Calgary'}
# {'total': 10, '_id': 'Lake Norman'}
# {'total': 10, '_id': 'North  York'}
# {'total': 10, '_id': 'Rockyview'}
# {'total': 10, '_id': 'Inglewood'}
# {'total': 10, '_id': 'Malton'}
# {'total': 10, '_id': 'Phoeniix'}
# {'total': 10, '_id': 'Candiac'}
# {'total': 10, '_id': 'Huntington Beach'}
# {'total': 10, '_id': 'Chandler-Gilbert'}
# {'total': 10, '_id': 'Silver Lake'}
# {'total': 10, '_id': 'Canonsburd'}
# {'total': 10, '_id': 'Division No. 6'}
# {'total': 9, '_id': 'Harwick'}
# {'total': 9, '_id': 'Gifford'}
# {'total': 9, '_id': 'Lynhurst'}
# {'total': 9, '_id': 'Ansnorveldt'}
# {'total': 9, '_id': 'Fisher'}
# {'total': 9, '_id': 'Farmington'}
# {'total': 9, '_id': 'Noyan'}
# {'total': 9, '_id': 'S Concord'}
# {'total': 9, '_id': 'Sainte-Therese'}
# {'total': 9, '_id': 'N. Ridgeville'}
# {'total': 9, '_id': 'Tolono'}
# {'total': 9, '_id': 'Char'}
# {'total': 9, '_id': 'Ingram'}
# {'total': 9, '_id': 'Hampstead'}
# {'total': 9, '_id': 'verdun'}
# {'total': 9, '_id': 'Moseley'}
# {'total': 9, '_id': 'Wellington'}
# {'total': 9, '_id': 'Brooklyn Hts.'}
# {'total': 9, '_id': 'Weston'}
# {'total': 9, '_id': 'Valleywide'}
# {'total': 9, '_id': 'Vaudreuil'}
# {'total': 9, '_id': 'GLENDALE'}
# {'total': 9, '_id': 'Côte-Saint-Luc'}
# {'total': 9, '_id': 'Bois-des-Filion'}
# {'total': 9, '_id': 'Monreoville'}
# {'total': 9, '_id': 'Sainte-Thérèse-de-Blainville'}
# {'total': 8, '_id': 'springdale'}
# {'total': 8, '_id': 'Montréal-West'}
# {'total': 8, '_id': 'Tucson'}
# {'total': 8, '_id': 'Union'}
# {'total': 8, '_id': 'Reminderville'}
# {'total': 8, '_id': 'Mooers'}
# {'total': 8, '_id': 'SW Calgary'}
# {'total': 8, '_id': 'SCARBOROUGH'}
# {'total': 8, '_id': 'Val-Morin'}
# {'total': 8, '_id': 'North Carolina'}
# {'total': 8, '_id': 'CLEVELAND'}
# {'total': 8, '_id': 'ETOBICOKE'}
# {'total': 8, '_id': 'Pointe-Calumet'}
# {'total': 8, '_id': 'solon'}
# {'total': 8, '_id': 'Huntsburg'}
# {'total': 8, '_id': 'Omaha'}
# {'total': 8, '_id': 'Mayfield Heights.'}
# {'total': 8, '_id': 'Las Vegass'}
# {'total': 8, '_id': 'North Las Vegas '}
# {'total': 8, '_id': 'Leeds'}
# {'total': 8, '_id': 'West Toronto'}
# {'total': 8, '_id': 'Nevada'}
# {'total': 8, '_id': 'McMurry'}
# {'total': 8, '_id': 'Surprise Crossing'}
# {'total': 8, '_id': 'Napierville'}
# {'total': 8, '_id': 'Old Town Scottsdale'}
# {'total': 7, '_id': 'Spartanburg'}
# {'total': 7, '_id': 'Valencia'}
# {'total': 7, '_id': 'Buena Vista'}
# {'total': 7, '_id': 'Mccandless Township'}
# {'total': 7, '_id': 'Westview'}
# {'total': 7, '_id': 'Old Brooklyn'}
# {'total': 7, '_id': 'Henderson and Las vegas'}
# {'total': 7, '_id': 'Mayfield Hts'}
# {'total': 7, '_id': 'AGINCOURT'}
# {'total': 7, '_id': 'St.Pittsburgh'}
# {'total': 7, '_id': 'Hemmingford'}
# {'total': 7, '_id': 'Avon lake'}
# {'total': 7, '_id': 'Coteau-du-Lac'}
# {'total': 7, '_id': 'Pepperpike'}
# {'total': 7, '_id': 'NEWMARKET'}
# {'total': 7, '_id': 'Decatur'}
# {'total': 7, '_id': 'Cote-Saint-Luc'}
# {'total': 7, '_id': 'Buckeye - Shaker'}
# {'total': 7, '_id': 'The Promenade'}
# {'total': 7, '_id': 'Plum Boro'}
# {'total': 7, '_id': 'Peninsul'}
# {'total': 7, '_id': 'Saint-Charles-Borromee'}
# {'total': 7, '_id': 'Lachenaie'}
# {'total': 7, '_id': 'La Vegas'}
# {'total': 7, '_id': 'Prévost'}
# {'total': 7, '_id': 'Ingomar'}
# {'total': 7, '_id': 'Garfield Hts'}
# {'total': 7, '_id': 'Mount Oliver'}
# {'total': 7, '_id': 'Norval'}
# {'total': 7, '_id': 'Sturgeon'}
# {'total': 6, '_id': 'Westworld Scottsdale'}
# {'total': 6, '_id': 'Chander'}
# {'total': 6, '_id': 'Broadlands'}
# {'total': 6, '_id': 'Huntingdon'}
# {'total': 6, '_id': 'Saintt-Bruno-de-Montarville'}
# {'total': 6, '_id': 'Beauharnois'}
# {'total': 6, '_id': 'San Tan'}
# {'total': 6, '_id': 'Shady Side'}
# {'total': 6, '_id': 'Quartier des Spectacles'}
# {'total': 6, '_id': 'Whtiby'}
# {'total': 6, '_id': 'North Braddock'}
# {'total': 6, '_id': 'Phoenix AZ'}
# {'total': 6, '_id': 'Sutersville'}
# {'total': 6, '_id': 'DENVER'}
# {'total': 6, '_id': 'CAVE CREEK'}
# {'total': 6, '_id': 'Montréal (Québec)'}
# {'total': 6, '_id': 'Warrendale'}
# {'total': 6, '_id': 'Charlemagne'}
# {'total': 6, '_id': 'Farnham'}
# {'total': 6, '_id': 'markham'}
# {'total': 6, '_id': 'Markham, ON'}
# {'total': 6, '_id': 'Litchfield park'}
# {'total': 6, '_id': 'Villa Grove'}
# {'total': 6, '_id': 'Chatauguay'}
# {'total': 6, '_id': 'Saint - Hyacinthe'}
# {'total': 6, '_id': 'THORNHILL'}
# {'total': 6, '_id': "L'ile-Bizard"}
# {'total': 6, '_id': 'Allegheny'}
# {'total': 6, '_id': 'Sunrise Manor'}
# {'total': 6, '_id': 'Kettleby'}
# {'total': 6, '_id': 'West Elizabeth'}
# {'total': 6, '_id': 'Lodi'}
# {'total': 6, '_id': 'NORTH YORK'}
# {'total': 6, '_id': 'Greenway'}
# {'total': 6, '_id': 'Woodbridge (Vaughan)'}
# {'total': 6, '_id': 'Zephyr'}
# {'total': 6, '_id': 'Cleveland, OH'}
# {'total': 6, '_id': 'Old Scottsdale'}
# {'total': 6, '_id': 'Deux-Montagnes Regional County Municipality'}
# {'total': 5, '_id': 'Henderson Nevada'}
# {'total': 5, '_id': "L'assomption"}
# {'total': 5, '_id': 'Sainte-Marthe'}
# {'total': 5, '_id': 'Whitney'}
# {'total': 5, '_id': 'Crescent'}
# {'total': 5, '_id': 'Chertsey'}
# {'total': 5, '_id': 'Rougemont'}
# {'total': 5, '_id': 'Rocky river'}
# {'total': 5, '_id': 'Cave Creek Road'}
# {'total': 5, '_id': 'Southside Flats'}
# {'total': 5, '_id': 'Beltline'}
# {'total': 5, '_id': 'Saint-Basile-Le-Grand'}
# {'total': 5, '_id': 'Leaside'}
# {'total': 5, '_id': 'Lake Las Vegas'}
# {'total': 5, '_id': 'East Gwilimbury'}
# {'total': 5, '_id': 'East Credit'}
# {'total': 5, '_id': 'St. Jean Sur Richelieu'}
# {'total': 5, '_id': 'Montville'}
# {'total': 5, '_id': 'Lindale'}
# {'total': 5, '_id': "De l'Eglise"}
# {'total': 5, '_id': 'Sage Hill'}
# {'total': 5, '_id': 'Mentor-On-The-Lake'}
# {'total': 5, '_id': 'Mesa Arizona'}
# {'total': 5, '_id': "Notre-Dame-De-L'ile-Perrot"}
# {'total': 5, '_id': 'Strip District'}
# {'total': 5, '_id': 'Bakerstown'}
# {'total': 5, '_id': 'Alburg'}
# {'total': 5, '_id': 'Fox Chapel'}
# {'total': 5, '_id': 'Northyork'}
# {'total': 5, '_id': 'Side Slopes'}
# {'total': 5, '_id': 'Agincourt'}
# {'total': 5, '_id': 'Otterburn Park'}
# {'total': 5, '_id': 'Île-des-Soeurs'}
# {'total': 5, '_id': 'Estrella Village'}
# {'total': 4, '_id': 'Saint-Isidore-de-Laprairie'}
# {'total': 4, '_id': 'Dublin'}
# {'total': 4, '_id': 'Mayfield Hts.'}
# {'total': 4, '_id': 'Glbert'}
# {'total': 4, '_id': 'south Euclid'}
# {'total': 4, '_id': 'Pheonix'}
# {'total': 4, '_id': 'Oakridges'}
# {'total': 4, '_id': 'Murrysville (Monroeville)'}
# {'total': 4, '_id': 'Sainte-Madeleine'}
# {'total': 4, '_id': 'Mississauaga'}
# {'total': 4, '_id': 'Centre Island'}
# {'total': 4, '_id': 'Nottingham Township'}
# {'total': 4, '_id': 'Nationwide'}
# {'total': 4, '_id': 'South Russell'}
# {'total': 4, '_id': 'Sainte-Marguerite-du-Lac-Masson'}
# {'total': 4, '_id': 'Saint-Bernard de Lacolle'}
# {'total': 4, '_id': 'Painesville Township'}
# {'total': 4, '_id': 'Claremont'}
# {'total': 4, '_id': 'Toronto-North York'}
# {'total': 4, '_id': 'Joliet'}
# {'total': 4, '_id': 'calgary'}
# {'total': 4, '_id': 'Phoniex'}
# {'total': 4, '_id': 'Pittsburch'}
# {'total': 4, '_id': 'Etobicoke,'}
# {'total': 4, '_id': 'QUEEN CREEK'}
# {'total': 4, '_id': 'Toronto Scarborough'}
# {'total': 4, '_id': 'Highland Hts'}
# {'total': 4, '_id': 'Palgrave'}
# {'total': 4, '_id': 'Bentleyville'}
# {'total': 4, '_id': 'Harmar Township'}
# {'total': 4, '_id': 'Mc Adenville'}
# {'total': 4, '_id': 'Rainbow Valley'}
# {'total': 4, '_id': 'Arizona'}
# {'total': 4, '_id': 'Venise-en-Québec'}
# {'total': 4, '_id': 'Stetson Valley'}
# {'total': 4, '_id': 'Point-Claire'}
# {'total': 4, '_id': 'St. Leonard'}
# {'total': 4, '_id': 'Down'}
# {'total': 4, '_id': 'Penn Hills Township'}
# {'total': 4, '_id': 'North Olmsted,'}
# {'total': 4, '_id': 'Milford'}
# {'total': 4, '_id': 'Sainte-Marguerite-du-lac-Masson'}
# {'total': 4, '_id': 'Monterey Park'}
# {'total': 4, '_id': 'Highland Park'}
# {'total': 4, '_id': 'Central Oakland'}
# {'total': 4, '_id': 'Dewey'}
# {'total': 4, '_id': 'North  Ridgeville'}
# {'total': 4, '_id': 'McKnight'}
# {'total': 4, '_id': 'Darlington'}
# {'total': 4, '_id': 'Saint Leonard'}
# {'total': 4, '_id': 'Cave creek'}
# {'total': 4, '_id': 'Draper'}
# {'total': 4, '_id': 'Newburgh Heights'}
# {'total': 4, '_id': 'Pasadena'}
# {'total': 4, '_id': "L'Assomption"}
# {'total': 4, '_id': 'Phoneix'}
# {'total': 4, '_id': 'Greensboro'}
# {'total': 4, '_id': 'Frazer'}
# {'total': 4, '_id': 'charlottte'}
# {'total': 4, '_id': 'Varennes'}
# {'total': 4, '_id': 'Sandy Ridge'}
# {'total': 4, '_id': 'Fithian'}
# {'total': 4, '_id': 'MATTHEWS'}
# {'total': 4, '_id': 'Saint-Pierre-de-Véronne-à-Pike-River'}
# {'total': 4, '_id': 'Yorkdale'}
# {'total': 4, '_id': 'montreal'}
# {'total': 4, '_id': 'Iberville'}
# {'total': 4, '_id': 'Paw Creek'}
# {'total': 4, '_id': 'Phoenix Valley'}
# {'total': 4, '_id': 'Richland Township'}
# {'total': 4, '_id': 'Mcdonald'}
# {'total': 4, '_id': 'Sainte-Marguerite-Esterel'}
# {'total': 4, '_id': 'Sale'}
# {'total': 4, '_id': 'Metro Phoenix'}
# {'total': 4, '_id': 'Closter'}
# {'total': 4, '_id': 'Mt. Washington'}
# {'total': 4, '_id': 'De Winton'}
# {'total': 4, '_id': 'Scotesdale'}
# {'total': 4, '_id': 'Snowflake'}
# {'total': 4, '_id': 'Auburn'}
# {'total': 4, '_id': 'Moon Twp.'}
# {'total': 3, '_id': 'Boston'}
# {'total': 3, '_id': 'Bloomfield'}
# {'total': 3, '_id': 'Midway'}
# {'total': 3, '_id': 'Ste-Dorothée'}
# {'total': 3, '_id': 'London'}
# {'total': 3, '_id': 'Austin'}
# {'total': 3, '_id': 'Toronto-West'}
# {'total': 3, '_id': 'St. Léonard'}
# {'total': 3, '_id': 'Lancaster'}
# {'total': 3, '_id': 'Ste-Therese-de-Blainville'}
# {'total': 3, '_id': 'Aliquippa'}
# {'total': 3, '_id': 'Deux-Montagnes'}
# {'total': 3, '_id': 'Lake Park'}
# {'total': 3, '_id': 'Lavaltrie'}
# {'total': 3, '_id': 'Streetsville'}
# {'total': 3, '_id': 'Oldham'}
# {'total': 3, '_id': 'Mansfield'}
# {'total': 3, '_id': "Baie-d'Urfé"}
# {'total': 3, '_id': 'New Glarus'}
# {'total': 3, '_id': 'Chattanooga'}
# {'total': 3, '_id': 'Scotsdale'}
# {'total': 3, '_id': 'Northeast Calgary'}
# {'total': 3, '_id': 'Ormstown'}
# {'total': 3, '_id': 'Port Vue'}
# {'total': 3, '_id': 'Citibank'}
# {'total': 3, '_id': 'peoria'}
# {'total': 3, '_id': 'N Solon'}
# {'total': 3, '_id': "O'hara Township"}
# {'total': 3, '_id': 'Montréal-Est'}
# {'total': 3, '_id': 'Scarbrough'}
# {'total': 3, '_id': 'Maricopa'}
# {'total': 3, '_id': 'Mississagua'}
# {'total': 3, '_id': 'Perry Twp'}
# {'total': 3, '_id': 'Vaughan Mills'}
# {'total': 3, '_id': 'Garrettsville'}
# {'total': 3, '_id': 'Medicine Hat'}
# {'total': 3, '_id': 'Laval, Pont Viau'}
# {'total': 3, '_id': 'Red Rock'}
# {'total': 3, '_id': 'Suncity'}
# {'total': 3, '_id': 'NorthYork'}
# {'total': 3, '_id': 'Alburgh'}
# {'total': 3, '_id': 'Crouse'}
# {'total': 3, '_id': 'Seattle'}
# {'total': 3, '_id': 'Los Vegas'}
# {'total': 3, '_id': 'Les Cèdres'}
# {'total': 3, '_id': 'Laval, Ste Dorothee'}
# {'total': 3, '_id': 'Apache Trail'}
# {'total': 3, '_id': 'Pickering Ajax Whitby'}
# {'total': 3, '_id': 'Uptown'}
# {'total': 3, '_id': 'Sun CIty'}
# {'total': 3, '_id': 'Lake Mead'}
# {'total': 3, '_id': 'Cleveland Hts.'}
# {'total': 3, '_id': 'Godmanchester'}
# {'total': 3, '_id': 'Las Vegas Nevada'}
# {'total': 3, '_id': 'SUN PRAIRIE'}
# {'total': 3, '_id': 'St-Lazare'}
# {'total': 3, '_id': 'Ivesdale'}
# {'total': 3, '_id': 'CALGARY'}
# {'total': 3, '_id': 'Las Vegas Valley'}
# {'total': 3, '_id': "Saint-Roch-de-l'Achigan"}
# {'total': 3, '_id': 'Hnederson'}
# {'total': 3, '_id': 'Las Vegas NV'}
# {'total': 3, '_id': 'Vieux-Montréal'}
# {'total': 3, '_id': 'Tempe '}
# {'total': 3, '_id': 'Middleburg'}
# {'total': 3, '_id': 'oakville'}
# {'total': 3, '_id': 'Les Coteaux'}
# {'total': 3, '_id': 'Maple Grove'}
# {'total': 3, '_id': 'Old Port of Montreal'}
# {'total': 3, '_id': 'Indian Land,'}
# {'total': 3, '_id': 'Queensville'}
# {'total': 3, '_id': ''}
# {'total': 3, '_id': 'Cranberry Township'}
# {'total': 3, '_id': 'St. Joseph'}
# {'total': 3, '_id': 'AZ'}
# {'total': 3, '_id': 'Henryville'}
# {'total': 3, '_id': 'St-Jean-sur-Richelieu'}
# {'total': 3, '_id': 'Hamilton'}
# {'total': 3, '_id': 'Toronto-Etobicoke'}
# {'total': 3, '_id': 'Edgemont'}
# {'total': 3, '_id': 'Bond Head'}
# {'total': 3, '_id': 'Concord Twp'}
# {'total': 3, '_id': 'Edmonton'}
# {'total': 3, '_id': 'Cleveland Height'}
# {'total': 3, '_id': 'Vaughn'}
# {'total': 3, '_id': 'East Hawkesbury'}
# {'total': 3, '_id': 'CARSON'}
# {'total': 3, '_id': 'Thomasboro'}
# {'total': 3, '_id': 'Saint-Basile-le-Grand'}
# {'total': 3, '_id': 'Richmond Height'}
# {'total': 3, '_id': 'Le Haut-Saint-Laurent Regional County Municipality'}
# {'total': 3, '_id': 'Sharon'}
# {'total': 3, '_id': 'McMasterville'}
# {'total': 3, '_id': 'las Vegas'}
# {'total': 3, '_id': 'St-Clet'}
# {'total': 3, '_id': 'Somerton'}
# {'total': 3, '_id': 'Sacramento'}
# {'total': 3, '_id': 'Morgan'}
# {'total': 3, '_id': 'Montreal-Est'}
# {'total': 3, '_id': 'Sun Praiie'}
# {'total': 3, '_id': 'Ange-Gardien'}
# {'total': 3, '_id': 'Rockyview County'}
# {'total': 3, '_id': 'Cote Saint Luc'}
# {'total': 3, '_id': 'CAREFREE'}
# {'total': 3, '_id': 'Scottsale'}
# {'total': 3, '_id': 'etobicoke'}
# {'total': 3, '_id': 'Warrenville'}
# {'total': 3, '_id': 'Evergreen'}
# {'total': 3, '_id': 'Fountain Hls'}
# {'total': 3, '_id': 'Pgh Int Arprt'}
# {'total': 3, '_id': 'Cuyohoga Falls'}
# {'total': 3, '_id': 'West Lake'}
# {'total': 3, '_id': 'Church Cove'}
# {'total': 3, '_id': 'Lacolle'}
# {'total': 3, '_id': 'Phoenix Metro Area'}
# {'total': 3, '_id': 'Manchester'}
# {'total': 3, '_id': 'Saint-laurent'}
# {'total': 3, '_id': 'Rockey View'}
# {'total': 3, '_id': 'Brownsburg-Chatham'}
# {'total': 3, '_id': 'Mississaugua'}
# {'total': 3, '_id': 'Oakwood village'}
# {'total': 3, '_id': 'North york'}
# {'total': 3, '_id': 'Las Vergas'}
# {'total': 3, '_id': 'Sainte-thérèse'}
# {'total': 3, '_id': 'Twinsburgh'}
# {'total': 3, '_id': 'St. Sauveur'}
# {'total': 3, '_id': 'Columbia Sta'}
# {'total': 3, '_id': 'North Phoenix'}
# {'total': 3, '_id': 'Bury'}
# {'total': 3, '_id': 'Belœil'}
# {'total': 3, '_id': 'Chateau'}
# {'total': 3, '_id': 'TOLLESON'}

# %% [markdown]
# Join name of entities to tip to find out the name of the place receiving the most tips

# %%
# aggregate tips
group_query = [{
    '$group'  :{
        '_id': '$business_id',
        'compliment_total': {'$sum': '$compliment_count'}
    }},{
    '$out': 'tip_aggregate_by_business'}]

group_result = mydb['tip'].aggregate(group_query)

# %%
# select name and business_id from business
group_query = [{
    '$project':{
        'business_id':1,
        'name':1
    }},{
    '$group' : { '_id' : "$business_id", 'name': { '$first': "$name" } } }
    ,
    {'$out': 'business_name'}]

group_result = mydb['business'].aggregate(group_query)

# %%
# join and sort
join_query = [
{
    '$lookup':{
        'from': 'business_name',
        'localField': '_id',
        'foreignField': '_id',
        'as': 'business_info'
    }}
    ,{
    '$project': {
        'compliment_total':1,
        'business_info.name':1,
        '_id':1
    }}
    ,
    {
    '$sort':{'compliment_total':-1}
    },
    {
    '$limit':10
    }
]

join_result = mydb['tip_aggregate_by_business'].aggregate(join_query)

# %%
for res in join_result:
    pprint.pprint(res)
# Out:
# {'_id': 'BQqwIYQuo2W94smjrBjy5g',
#  'business_info': [{'name': 'Il Chianti Italian Steak & Seafood'}],
#  'compliment_total': 204}
# {'_id': 'FaHADZARwnY4yvlvpnsfGA',
#  'business_info': [{'name': 'McCarran International Airport'}],
#  'compliment_total': 162}
# {'_id': 'RESDUcs7fIiihp38-d6_6g',
#  'business_info': [{'name': 'Bacchanal Buffet'}],
#  'compliment_total': 150}
# {'_id': '55E0-qUHa7Kzqz8rOhbdBQ',
#  'business_info': [{'name': 'Costco Gasoline'}],
#  'compliment_total': 120}
# {'_id': 'MpmFFw0GE_2iRFPdsRpJbA',
#  'business_info': [{'name': 'XS Nightclub'}],
#  'compliment_total': 111}
# {'_id': 'JmI9nslLD7KZqRr__Bg6NQ',
#  'business_info': [{'name': 'Phoenix Sky Harbor International Airport'}],
#  'compliment_total': 105}
# {'_id': 'DN0b4Un8--Uf6SEWLeh0UA',
#  'business_info': [{'name': "Amy's Baking Company"}],
#  'compliment_total': 102}
# {'_id': 'QsKhwKYB3YeWXqpIPd5QMg',
#  'business_info': [{'name': 'Sonoma Cellar'}],
#  'compliment_total': 93}
# {'_id': 'QhXBIQWUmQxuVErdwY2QVw',
#  'business_info': [{'name': 'Manila BBQ'}],
#  'compliment_total': 93}
# {'_id': 'OMRYQihVjqqzjoNoQgyhgQ',
#  'business_info': [{'name': "Sister's Oriental Market & Video"}],
#  'compliment_total': 87}
