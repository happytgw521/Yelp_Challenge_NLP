# %%
import pymongo
import json
import pprint

# %%
myclient = pymongo.MongoClient("mongodb://localhost:27017/")
mydb = myclient["yelpdb"]

# %%
mydb.collection_names()
# Out:
# ['photo',
#  'tip_aggregate_by_business',
#  'user',
#  'business_name',
#  'business',
#  'review',
#  'tip',
#  'checkin']

# %% [markdown]
# Perform MongoDB query within one collection

# %%
# Top 10 Chinese / Japanese restaurants in Las Vegas with count of review > 500
myquery = {
    "categories": {"$regex": ".*Chinese.*|.*Japanese.*" },
    "city": "Las Vegas",
    "review_count": {"$gt": 500},
    "is_open":1
}

query_result = mydb['business'].find(myquery, {'name':1}).sort("stars",-1).limit(10)
for res in query_result:
    pprint.pprint(res)
# Out:
# {'_id': ObjectId('5c719e093d10166478cba143'), 'name': 'Pan Asian'}
# {'_id': ObjectId('5c719e093d10166478cbb798'), 'name': 'Island Style Restaurant'}
# {'_id': ObjectId('5c719e093d10166478cc0168'),
#  'name': 'Kaizen Fusion Roll and Sushi'}
# {'_id': ObjectId('5c719e0a3d10166478cc2070'), 'name': 'Cafe Sanuki'}
# {'_id': ObjectId('5c719e0a3d10166478cc358f'),
#  'name': "Naked Fish's Sushi & Grill"}
# {'_id': ObjectId('5c719e0a3d10166478cc4e71'), 'name': 'Tonkatsu Kiyoshi'}
# {'_id': ObjectId('5c719e0a3d10166478cc8e3e'), 'name': 'Shang Artisan Noodle'}
# {'_id': ObjectId('5c719e0a3d10166478cc8ea4'), 'name': 'Jjanga Steak & Sushi'}
# {'_id': ObjectId('5c719e0a3d10166478cc94d6'),
#  'name': 'Soho Japanese Restaurant'}
# {'_id': ObjectId('5c719e0a3d10166478cca5ff'), 'name': 'Sweets Raku'}

# %%
# Count of review per city (Aggregate), sorted by counts
myaggregate = [{
    "$match": {'is_open':1}}, 
    {"$group": {'_id': '$city',
               'total': {'$sum': '$review_count'}}},
    {'$sort': {'total':-1}}]

aggregate_result = mydb['business'].aggregate(myaggregate)
for record in aggregate_result:
    print(record)
# Out:
# {'total': 5100993, '_id': 'Las Vegas'}
# {'total': 1865718, '_id': 'Phoenix'}
# {'total': 1267338, '_id': 'Toronto'}
# {'total': 951900, '_id': 'Scottsdale'}
# {'total': 795114, '_id': 'Charlotte'}
# {'total': 574827, '_id': 'Pittsburgh'}
# {'total': 556995, '_id': 'Henderson'}
# {'total': 506871, '_id': 'Tempe'}
# {'total': 435267, '_id': 'Mesa'}
# {'total': 394278, '_id': 'Montréal'}
# {'total': 391779, '_id': 'Chandler'}
# {'total': 335211, '_id': 'Gilbert'}
# {'total': 293106, '_id': 'Cleveland'}
# {'total': 262719, '_id': 'Madison'}
# {'total': 258030, '_id': 'Glendale'}
# {'total': 245271, '_id': 'Calgary'}
# {'total': 148860, '_id': 'Peoria'}
# {'total': 142626, '_id': 'Mississauga'}
# {'total': 131478, '_id': 'North Las Vegas'}
# {'total': 127275, '_id': 'Markham'}
# {'total': 88980, '_id': 'Surprise'}
# {'total': 76803, '_id': 'Goodyear'}
# {'total': 75648, '_id': 'Champaign'}
# {'total': 59631, '_id': 'Richmond Hill'}
# {'total': 59580, '_id': 'Avondale'}
# {'total': 50505, '_id': 'North York'}
# {'total': 48915, '_id': 'Concord'}
# {'total': 48099, '_id': 'Scarborough'}
# {'total': 46551, '_id': 'Lakewood'}
# {'total': 41220, '_id': 'Vaughan'}
# {'total': 40641, '_id': 'Huntersville'}
# {'total': 37929, '_id': 'Matthews'}
# {'total': 33435, '_id': 'Etobicoke'}
# {'total': 32094, '_id': 'Brampton'}
# {'total': 31401, '_id': 'Cave Creek'}
# {'total': 29787, '_id': 'Fort Mill'}
# {'total': 24579, '_id': 'Akron'}
# {'total': 24402, '_id': 'Boulder City'}
# {'total': 23646, '_id': 'Cornelius'}
# {'total': 23514, '_id': 'Westlake'}
# {'total': 22119, '_id': 'Thornhill'}
# {'total': 21483, '_id': 'Urbana'}
# {'total': 21099, '_id': 'Middleton'}
# {'total': 20658, '_id': 'Cleveland Heights'}
# {'total': 19176, '_id': 'Strongsville'}
# {'total': 18552, '_id': 'Gastonia'}
# {'total': 18459, '_id': 'Pineville'}
# {'total': 18261, '_id': 'Litchfield Park'}
# {'total': 17805, '_id': 'Fountain Hills'}
# {'total': 17766, '_id': 'Mentor'}
# {'total': 17532, '_id': 'Cuyahoga Falls'}
# {'total': 17322, '_id': 'Rocky River'}
# {'total': 17286, '_id': 'Monroeville'}
# {'total': 17256, '_id': 'North Olmsted'}
# {'total': 15630, '_id': 'Parma'}
# {'total': 14298, '_id': 'Beachwood'}
# {'total': 13377, '_id': 'Rock Hill'}
# {'total': 13314, '_id': 'Montreal'}
# {'total': 13143, '_id': 'Paradise Valley'}
# {'total': 12987, '_id': 'Aurora'}
# {'total': 12912, '_id': 'Kent'}
# {'total': 12897, '_id': 'Medina'}
# {'total': 11931, '_id': 'Oakville'}
# {'total': 11751, '_id': 'Independence'}
# {'total': 11505, '_id': 'Wexford'}
# {'total': 11484, '_id': 'Fitchburg'}
# {'total': 10938, '_id': 'Newmarket'}
# {'total': 10770, '_id': 'Solon'}
# {'total': 10635, '_id': 'Willoughby'}
# {'total': 10575, '_id': 'Indian Trail'}
# {'total': 10248, '_id': 'Avon'}
# {'total': 10215, '_id': 'Hudson'}
# {'total': 9975, '_id': 'Sun City'}
# {'total': 9948, '_id': 'Sun Prairie'}
# {'total': 9657, '_id': 'Homestead'}
# {'total': 9597, '_id': 'Pickering'}
# {'total': 9564, '_id': 'Laval'}
# {'total': 9489, '_id': 'Stow'}
# {'total': 9342, '_id': 'Belmont'}
# {'total': 9249, '_id': 'Bridgeville'}
# {'total': 9156, '_id': 'Davidson'}
# {'total': 8775, '_id': 'Woodmere'}
# {'total': 8715, '_id': 'Chagrin Falls'}
# {'total': 8496, '_id': 'Ajax'}
# {'total': 8442, '_id': 'Queen Creek'}
# {'total': 8307, '_id': 'Tolleson'}
# {'total': 7989, '_id': 'Laveen'}
# {'total': 7914, '_id': 'Woodbridge'}
# {'total': 7893, '_id': 'Coraopolis'}
# {'total': 7563, '_id': 'Bethel Park'}
# {'total': 7428, '_id': 'Whitby'}
# {'total': 7287, '_id': 'Lyndhurst'}
# {'total': 7146, '_id': 'Fairlawn'}
# {'total': 7002, '_id': 'Verona'}
# {'total': 6732, '_id': 'Carnegie'}
# {'total': 6723, '_id': 'Mayfield Heights'}
# {'total': 6609, '_id': 'Monona'}
# {'total': 6591, '_id': 'Canonsburg'}
# {'total': 6585, '_id': 'Waxhaw'}
# {'total': 6525, '_id': 'Fairview Park'}
# {'total': 6288, '_id': 'Twinsburg'}
# {'total': 6273, '_id': 'Middleburg Heights'}
# {'total': 5943, '_id': 'Berea'}
# {'total': 5835, '_id': 'Brunswick'}
# {'total': 5640, '_id': 'Elyria'}
# {'total': 5049, '_id': 'Sewickley'}
# {'total': 5043, '_id': 'Streetsboro'}
# {'total': 4962, '_id': 'Avon Lake'}
# {'total': 4935, '_id': 'El Mirage'}
# {'total': 4809, '_id': 'Unionville'}
# {'total': 4779, '_id': 'Brossard'}
# {'total': 4740, '_id': 'Verdun'}
# {'total': 4662, '_id': 'LAS VEGAS'}
# {'total': 4629, '_id': 'East York'}
# {'total': 4566, '_id': 'Harrisburg'}
# {'total': 4539, '_id': 'North Royalton'}
# {'total': 4482, '_id': 'Monroe'}
# {'total': 4470, '_id': 'Buckeye'}
# {'total': 4422, '_id': 'Brooklyn'}
# {'total': 4386, '_id': 'Spring Valley'}
# {'total': 4380, '_id': 'West Mifflin'}
# {'total': 4323, '_id': 'Denver'}
# {'total': 4299, '_id': 'Mint Hill'}
# {'total': 4287, '_id': 'Painesville'}
# {'total': 4248, '_id': 'Murrysville'}
# {'total': 4161, '_id': 'Macedonia'}
# {'total': 4140, '_id': 'Carefree'}
# {'total': 4119, '_id': 'Broadview Heights'}
# {'total': 4053, '_id': 'Dorval'}
# {'total': 3624, '_id': 'Saint-Laurent'}
# {'total': 3591, '_id': 'Amherst'}
# {'total': 3540, '_id': 'McMurray'}
# {'total': 3519, '_id': 'Sun City West'}
# {'total': 3504, '_id': 'Northfield'}
# {'total': 3501, '_id': 'Stoughton'}
# {'total': 3477, '_id': 'Brecksville'}
# {'total': 3369, '_id': 'Valley View'}
# {'total': 3342, '_id': 'York'}
# {'total': 3330, '_id': 'Bedford'}
# {'total': 3291, '_id': 'Gibsonia'}
# {'total': 3246, '_id': 'Indian Land'}
# {'total': 3198, '_id': 'Airdrie'}
# {'total': 3135, '_id': 'Oakmont'}
# {'total': 3117, '_id': 'Dollard-des-Ormeaux'}
# {'total': 3108, '_id': 'South Euclid'}
# {'total': 3099, '_id': 'Moon Township'}
# {'total': 3072, '_id': 'Chesterland'}
# {'total': 3000, '_id': 'Allison Park'}
# {'total': 2958, '_id': 'Ahwatukee'}
# {'total': 2886, '_id': 'Savoy'}
# {'total': 2868, '_id': 'University Heights'}
# {'total': 2859, '_id': 'Pointe-Claire'}
# {'total': 2823, '_id': 'Euclid'}
# {'total': 2781, '_id': 'Kannapolis'}
# {'total': 2757, '_id': 'North Ridgeville'}
# {'total': 2751, '_id': 'Lorain'}
# {'total': 2700, '_id': 'West Homestead'}
# {'total': 2685, '_id': 'Westmount'}
# {'total': 2583, '_id': 'Warrensville Heights'}
# {'total': 2556, '_id': 'Chardon'}
# {'total': 2502, '_id': 'Youngtown'}
# {'total': 2487, '_id': 'Olmsted Falls'}
# {'total': 2466, '_id': 'Waunakee'}
# {'total': 2433, '_id': 'New Kensington'}
# {'total': 2382, '_id': 'Lake Wylie'}
# {'total': 2364, '_id': 'Highland Heights'}
# {'total': 2301, '_id': 'Parma Heights'}
# {'total': 2292, '_id': 'Peninsula'}
# {'total': 2274, '_id': 'Orange Village'}
# {'total': 2250, '_id': 'Tega Cay'}
# {'total': 2184, '_id': 'Seven Hills'}
# {'total': 2160, '_id': 'Irwin'}
# {'total': 2160, '_id': 'South Las Vegas'}
# {'total': 2103, '_id': 'Wickliffe'}
# {'total': 2100, '_id': 'Anthem'}
# {'total': 2085, '_id': 'McKees Rocks'}
# {'total': 2070, '_id': 'Mount Holly'}
# {'total': 2031, '_id': 'Mount Horeb'}
# {'total': 2028, '_id': 'Willoughby Hills'}
# {'total': 2013, '_id': 'Clover'}
# {'total': 2004, '_id': 'Oregon'}
# {'total': 1986, '_id': 'Eastlake'}
# {'total': 1983, '_id': 'Maple'}
# {'total': 1959, '_id': 'Brook Park'}
# {'total': 1917, '_id': 'Willowick'}
# {'total': 1851, '_id': 'Glenshaw'}
# {'total': 1845, '_id': 'Bellevue'}
# {'total': 1818, '_id': 'Tarentum'}
# {'total': 1776, '_id': 'Blue Diamond'}
# {'total': 1713, '_id': 'Stouffville'}
# {'total': 1686, '_id': 'Higley'}
# {'total': 1680, '_id': 'Shaker Heights'}
# {'total': 1677, '_id': 'Whitchurch-Stouffville'}
# {'total': 1674, '_id': 'Pleasant Hills'}
# {'total': 1635, '_id': 'Bay Village'}
# {'total': 1584, '_id': 'N. Las Vegas'}
# {'total': 1581, '_id': 'Richfield'}
# {'total': 1566, '_id': 'Tallmadge'}
# {'total': 1557, '_id': 'Robinson Township'}
# {'total': 1509, '_id': 'Lasalle'}
# {'total': 1500, '_id': 'Outremont'}
# {'total': 1455, '_id': 'Mooresville'}
# {'total': 1449, '_id': 'Missisauga'}
# {'total': 1416, '_id': 'Stallings'}
# {'total': 1401, '_id': 'Wesley Chapel'}
# {'total': 1395, '_id': 'North Versailles'}
# {'total': 1374, '_id': 'Longueuil'}
# {'total': 1371, '_id': 'HENDERSON'}
# {'total': 1314, '_id': 'Las  Vegas'}
# {'total': 1311, '_id': 'Guadalupe'}
# {'total': 1302, '_id': 'DeForest'}
# {'total': 1257, '_id': 'McKeesport'}
# {'total': 1251, '_id': 'Lachine'}
# {'total': 1242, '_id': 'Pepper Pike'}
# {'total': 1236, '_id': 'Oakdale'}
# {'total': 1215, '_id': 'North Huntingdon'}
# {'total': 1188, '_id': 'Braddock'}
# {'total': 1185, '_id': 'Burton'}
# {'total': 1182, '_id': 'N Las Vegas'}
# {'total': 1158, '_id': 'Mayfield'}
# {'total': 1155, '_id': 'Cottage Grove'}
# {'total': 1152, '_id': 'Mt. Lebanon'}
# {'total': 1152, '_id': 'Richmond Heights'}
# {'total': 1149, '_id': 'Pierrefonds'}
# {'total': 1140, '_id': 'Saint-Sauveur'}
# {'total': 1137, '_id': 'Mahomet'}
# {'total': 1113, '_id': 'Garfield Heights'}
# {'total': 1092, '_id': 'Mc Kees Rocks'}
# {'total': 1071, '_id': 'Wadsworth'}
# {'total': 1053, '_id': 'Cross Plains'}
# {'total': 1050, '_id': 'Apache Junction'}
# {'total': 1032, '_id': 'Sun Lakes'}
# {'total': 1017, '_id': 'Copley'}
# {'total': 1017, '_id': 'White Oak'}
# {'total': 1011, '_id': 'Fort McDowell'}
# {'total': 1005, '_id': 'Ambridge'}
# {'total': 1002, '_id': 'Kirkland'}
# {'total': 969, '_id': 'MESA'}
# {'total': 966, '_id': 'Munhall'}
# {'total': 951, '_id': 'Sheffield Village'}
# {'total': 945, '_id': 'Blakeney'}
# {'total': 939, '_id': 'Kirtland'}
# {'total': 936, '_id': 'Rantoul'}
# {'total': 927, '_id': 'Lower Lawrenceville'}
# {'total': 912, '_id': 'Vaudreuil-Dorion'}
# {'total': 912, '_id': 'Moreland Hills'}
# {'total': 909, '_id': 'Halton Hills'}
# {'total': 894, '_id': 'Enterprise'}
# {'total': 888, '_id': 'Mayfield Village'}
# {'total': 882, '_id': 'Tremont'}
# {'total': 882, '_id': 'Upper St Clair'}
# {'total': 876, '_id': 'Woodmere Village'}
# {'total': 870, '_id': 'McFarland'}
# {'total': 855, '_id': 'Scottdale'}
# {'total': 849, '_id': 'Millvale'}
# {'total': 840, '_id': 'Middlefield'}
# {'total': 831, '_id': 'Georgetown'}
# {'total': 825, '_id': 'Cecil'}
# {'total': 813, '_id': 'Mount Lebanon'}
# {'total': 810, '_id': 'Cramerton'}
# {'total': 804, '_id': 'Springdale'}
# {'total': 804, '_id': 'Maple Heights'}
# {'total': 801, '_id': 'Paradise'}
# {'total': 789, '_id': 'Monticello'}
# {'total': 789, '_id': 'Bolton'}
# {'total': 786, '_id': 'Ross Township'}
# {'total': 783, '_id': 'Elizabeth'}
# {'total': 777, '_id': 'Windsor'}
# {'total': 771, '_id': 'Orange'}
# {'total': 771, '_id': 'Grand River'}
# {'total': 765, '_id': 'Munroe Falls'}
# {'total': 765, '_id': 'De Forest'}
# {'total': 765, '_id': 'Bedford Heights'}
# {'total': 762, '_id': 'Rocky View'}
# {'total': 762, '_id': 'North Randall'}
# {'total': 756, '_id': 'LasVegas'}
# {'total': 756, '_id': 'West View'}
# {'total': 744, '_id': 'Las vegas'}
# {'total': 732, '_id': 'Robinson'}
# {'total': 720, '_id': 'East Gwillimbury'}
# {'total': 717, '_id': 'Summerlin'}
# {'total': 711, '_id': 'King City'}
# {'total': 705, '_id': 'Concord Mills'}
# {'total': 702, '_id': 'Heidelberg'}
# {'total': 702, '_id': 'Laveen Village'}
# {'total': 702, '_id': 'Clark'}
# {'total': 696, '_id': 'Turtle Creek'}
# {'total': 687, '_id': 'Valley City'}
# {'total': 687, '_id': 'Bradford'}
# {'total': 684, '_id': 'Mont-Royal'}
# {'total': 666, '_id': 'Lowell'}
# {'total': 663, '_id': 'Caledon'}
# {'total': 645, '_id': 'Aspinwall'}
# {'total': 636, '_id': 'Brentwood'}
# {'total': 636, '_id': 'Mc Farland'}
# {'total': 636, '_id': 'Mentor-on-the-Lake'}
# {'total': 630, '_id': 'Sharpsburg'}
# {'total': 603, '_id': 'Upper Saint Clair'}
# {'total': 603, '_id': 'Leetsdale'}
# {'total': 600, '_id': 'Crafton'}
# {'total': 600, '_id': 'Newbury'}
# {'total': 594, '_id': 'Grafton'}
# {'total': 594, '_id': 'Rexdale'}
# {'total': 591, '_id': 'Penn Hills'}
# {'total': 591, '_id': "L'Île-Perrot"}
# {'total': 579, '_id': 'TEMPE'}
# {'total': 579, '_id': 'Belleville'}
# {'total': 567, '_id': 'Columbia Station'}
# {'total': 558, '_id': 'Finleyville'}
# {'total': 549, '_id': 'Dallas'}
# {'total': 534, '_id': 'Boucherville'}
# {'total': 534, '_id': 'Brookpark'}
# {'total': 534, '_id': 'Trafford'}
# {'total': 525, '_id': 'Etna'}
# {'total': 519, '_id': 'Clairton'}
# {'total': 516, '_id': 'Norton'}
# {'total': 504, '_id': 'Imperial'}
# {'total': 498, '_id': 'Bradford West Gwillimbury'}
# {'total': 498, '_id': 'Fairport Harbor'}
# {'total': 468, '_id': 'Nellis AFB'}
# {'total': 465, '_id': 'Sainte-Anne-de-Bellevue'}
# {'total': 462, '_id': 'Tornto'}
# {'total': 459, '_id': 'CHARLOTTE'}
# {'total': 459, '_id': 'Hampton Township'}
# {'total': 456, '_id': 'Cheswick'}
# {'total': 456, '_id': 'Greenfield Park'}
# {'total': 453, '_id': 'Dollard-Des-Ormeaux'}
# {'total': 453, '_id': 'Saint-Jean-sur-Richelieu'}
# {'total': 441, '_id': 'Locust'}
# {'total': 432, '_id': 'Saint-Lambert'}
# {'total': 429, '_id': 'Hinckley'}
# {'total': 423, '_id': 'McCandless Township'}
# {'total': 420, '_id': 'Midland'}
# {'total': 417, '_id': 'Anjou'}
# {'total': 411, '_id': 'charlotte'}
# {'total': 411, '_id': 'La Prairie'}
# {'total': 408, '_id': 'Saint-Hubert'}
# {'total': 408, '_id': 'Moon'}
# {'total': 402, '_id': 'las vegas'}
# {'total': 399, '_id': 'Waddell'}
# {'total': 399, '_id': 'Stanley'}
# {'total': 396, '_id': 'Chestermere'}
# {'total': 390, '_id': 'South Park Township'}
# {'total': 390, '_id': 'Wilkinsburg'}
# {'total': 387, '_id': 'Mt Lebanon'}
# {'total': 384, '_id': 'Saint-Leonard'}
# {'total': 381, '_id': 'Don Mills'}
# {'total': 369, '_id': 'Mc Murray'}
# {'total': 360, '_id': 'Montrose'}
# {'total': 357, '_id': 'Gates Mills'}
# {'total': 357, '_id': 'GILBERT'}
# {'total': 354, '_id': 'Weddington'}
# {'total': 354, '_id': 'Plum'}
# {'total': 351, '_id': 'Port Credit'}
# {'total': 342, '_id': 'Castle Shannon'}
# {'total': 342, '_id': 'Robinson Twp.'}
# {'total': 336, '_id': 'Monongahela'}
# {'total': 333, '_id': 'Lawrenceville'}
# {'total': 330, '_id': 'South Park'}
# {'total': 330, '_id': 'Emsworth'}
# {'total': 324, '_id': 'Saint-Léonard'}
# {'total': 324, '_id': 'Glendale Az'}
# {'total': 318, '_id': 'Mckees Rocks'}
# {'total': 318, '_id': 'LaSalle'}
# {'total': 312, '_id': 'Harrison City'}
# {'total': 309, '_id': 'Downtown'}
# {'total': 303, '_id': 'Charlotte '}
# {'total': 303, '_id': 'lyndhurst'}
# {'total': 297, '_id': 'W Henderson'}
# {'total': 297, '_id': 'Ravenna'}
# {'total': 294, '_id': 'Montral'}
# {'total': 294, '_id': 'Kleinburg'}
# {'total': 294, '_id': 'Green Tree'}
# {'total': 288, '_id': 'Oakland'}
# {'total': 288, '_id': 'Lower Burrell'}
# {'total': 288, '_id': 'Saint-Jérôme'}
# {'total': 288, '_id': 'Sheffield'}
# {'total': 285, '_id': 'Pittsburg'}
# {'total': 282, '_id': 'Walton Hills'}
# {'total': 279, '_id': 'Chambly'}
# {'total': 276, '_id': 'Saint Joseph'}
# {'total': 273, '_id': 'SCOTTSDALE'}
# {'total': 273, '_id': 'Boisbriand'}
# {'total': 270, '_id': 'Brooklin'}
# {'total': 270, '_id': 'Saint-Eustache'}
# {'total': 267, '_id': 'Las Vegas '}
# {'total': 267, '_id': 'Brookline'}
# {'total': 264, '_id': 'Presto'}
# {'total': 258, '_id': 'Swissvale'}
# {'total': 249, '_id': 'phoenix'}
# {'total': 249, '_id': 'Jefferson Hills'}
# {'total': 246, '_id': 'NORTH LAS VEGAS'}
# {'total': 246, '_id': 'Upper St. Clair'}
# {'total': 243, '_id': 'Dravosburg'}
# {'total': 240, '_id': 'Rosemère'}
# {'total': 240, '_id': 'Las Vegas & Henderson'}
# {'total': 237, '_id': 'Shadyside'}
# {'total': 231, '_id': 'Champlain'}
# {'total': 228, '_id': 'McAdenville'}
# {'total': 228, '_id': 'Wilmerding'}
# {'total': 225, '_id': 'Milton'}
# {'total': 222, '_id': 'N W Las Vegas'}
# {'total': 222, '_id': 'Etibicoke'}
# {'total': 222, '_id': 'Peters Township'}
# {'total': 222, '_id': 'N Ridgeville'}
# {'total': 222, '_id': 'Terrebonne'}
# {'total': 219, '_id': 'St-Benoît de Mirabel'}
# {'total': 219, '_id': 'W Spring Valley'}
# {'total': 216, '_id': 'Sauk City'}
# {'total': 210, '_id': 'Sheffield Lake'}
# {'total': 210, '_id': 'McCandless'}
# {'total': 210, '_id': 'Olmsted Township'}
# {'total': 210, '_id': 'Mcmurray'}
# {'total': 207, '_id': 'Montréal-Ouest'}
# {'total': 204, '_id': 'Rouses Point'}
# {'total': 201, '_id': 'Henderston'}
# {'total': 201, '_id': 'Mint  Hill'}
# {'total': 201, '_id': 'PHOENIX'}
# {'total': 198, '_id': 'Black Earth'}
# {'total': 198, '_id': 'Bath'}
# {'total': 198, '_id': 'Nobleton'}
# {'total': 198, '_id': 'Sagamore Hills'}
# {'total': 195, '_id': 'Centennial Hills'}
# {'total': 195, '_id': 'Mantua'}
# {'total': 195, '_id': 'Sainte-Julie'}
# {'total': 195, '_id': 'Beaconsfield'}
# {'total': 192, '_id': 'Vegas'}
# {'total': 192, '_id': 'SURPRISE'}
# {'total': 189, '_id': 'MADISON'}
# {'total': 189, '_id': 'West Montréal'}
# {'total': 186, '_id': 'North Olmstead'}
# {'total': 186, '_id': 'Middleburg Hts'}
# {'total': 183, '_id': 'Oakwood Village'}
# {'total': 183, '_id': 'Uxbridge'}
# {'total': 183, '_id': 'Rocky View County'}
# {'total': 180, '_id': 'East Liberty'}
# {'total': 180, '_id': 'Mc Donald'}
# {'total': 177, '_id': 'Avalon'}
# {'total': 177, '_id': 'Wilkins Township'}
# {'total': 177, '_id': 'Harmarville'}
# {'total': 177, '_id': 'Sainte-Adèle'}
# {'total': 174, '_id': 'Gormley'}
# {'total': 174, '_id': 'Litchfield'}
# {'total': 174, '_id': 'Fort Mcdowell'}
# {'total': 171, '_id': 'Vimont'}
# {'total': 171, '_id': 'Dormont'}
# {'total': 171, '_id': 'Deforest'}
# {'total': 171, '_id': 'boulder city'}
# {'total': 171, '_id': 'Dollard-des Ormeaux'}
# {'total': 168, '_id': 'scottsdale'}
# {'total': 168, '_id': 'Châteauguay'}
# {'total': 165, '_id': 'Mcfarland'}
# {'total': 165, '_id': 'Bainbridge'}
# {'total': 165, '_id': 'Montreal-Nord'}
# {'total': 159, '_id': 'Paoli'}
# {'total': 159, '_id': 'Medina Township'}
# {'total': 159, '_id': 'Mentor On The Lake'}
# {'total': 159, '_id': 'Blawnox'}
# {'total': 159, '_id': 'Sainte-Anne-De-Bellevue'}
# {'total': 159, '_id': 'Ben Avon'}
# {'total': 156, '_id': 'Baldwin'}
# {'total': 156, '_id': 'Library'}
# {'total': 153, '_id': 'Russellton'}
# {'total': 153, '_id': 'RIchmond Hill'}
# {'total': 153, '_id': 'Saint-Lazare'}
# {'total': 150, '_id': 'Schaumburg'}
# {'total': 150, '_id': 'Mirabel'}
# {'total': 150, '_id': 'Blainville'}
# {'total': 147, '_id': 'La Salle'}
# {'total': 147, '_id': 'Export'}
# {'total': 147, '_id': 'St Joseph'}
# {'total': 144, '_id': 'York Regional Municipality'}
# {'total': 144, '_id': 'Tuscola'}
# {'total': 144, '_id': 'Arnold'}
# {'total': 144, '_id': 'East McKeesport'}
# {'total': 141, '_id': 'Saint-Hyacinthe'}
# {'total': 141, '_id': 'henderson'}
# {'total': 141, '_id': 'Sainte-Thérèse'}
# {'total': 141, '_id': 'Harrisbug'}
# {'total': 138, '_id': 'C Las Vegas'}
# {'total': 135, '_id': 'Lower burrell'}
# {'total': 135, '_id': 'GOODYEAR'}
# {'total': 135, '_id': 'Île des Soeurs'}
# {'total': 135, '_id': 'Beloeil'}
# {'total': 135, '_id': 'Squirrel Hill'}
# {'total': 132, '_id': 'Oakwood'}
# {'total': 129, '_id': 'Neville Island'}
# {'total': 129, '_id': 'McDonald'}
# {'total': 129, '_id': 'Balzac'}
# {'total': 129, '_id': 'Warrensville Hts.'}
# {'total': 129, '_id': 'Ogden'}
# {'total': 129, '_id': 'Hiram'}
# {'total': 126, '_id': 'Elizabeth Township'}
# {'total': 126, '_id': 'Sunrise'}
# {'total': 126, '_id': 'Willowdale'}
# {'total': 126, '_id': 'mesa'}
# {'total': 123, '_id': 'Waterloo'}
# {'total': 123, '_id': 'Mont-Saint-Hilaire'}
# {'total': 123, '_id': 'Delson'}
# {'total': 123, '_id': 'Dollard-Des Ormeaux'}
# {'total': 120, '_id': 'Central Henderson'}
# {'total': 117, '_id': 'Henderson (Green Valley)'}
# {'total': 117, '_id': 'Mentor On the'}
# {'total': 117, '_id': 'Caledon East'}
# {'total': 117, '_id': 'King'}
# {'total': 114, '_id': 'PEORIA'}
# {'total': 114, '_id': 'Rigaud'}
# {'total': 114, '_id': 'Dane'}
# {'total': 114, '_id': 'Saint-Jerome'}
# {'total': 114, '_id': 'Sainte-Adele'}
# {'total': 114, '_id': 'Lowesville'}
# {'total': 114, '_id': 'South Charlotte'}
# {'total': 111, '_id': 'Ranlo'}
# {'total': 111, '_id': 'Phoenix, AZ'}
# {'total': 111, '_id': 'Schomberg'}
# {'total': 111, '_id': 'Saint-Bernard-de-Lacolle'}
# {'total': 111, '_id': 'Rio Verde'}
# {'total': 108, '_id': 'Toronto Division'}
# {'total': 108, '_id': 'Saint-Constant'}
# {'total': 108, '_id': 'Glassport'}
# {'total': 108, '_id': 'Lagrange'}
# {'total': 105, '_id': 'Las Vegas East'}
# {'total': 105, '_id': 'East Ajax'}
# {'total': 105, '_id': 'Herminie'}
# {'total': 105, '_id': 'GIlbert'}
# {'total': 105, '_id': 'Midnapore'}
# {'total': 105, '_id': 'Forest Hills'}
# {'total': 105, '_id': 'NELLIS AFB'}
# {'total': 105, '_id': 'San Diego'}
# {'total': 102, '_id': 'North Hills'}
# {'total': 102, '_id': 'Broadview Hts'}
# {'total': 102, '_id': 'LAVEEN'}
# {'total': 102, '_id': 'Lachute'}
# {'total': 102, '_id': 'Indian land'}
# {'total': 99, '_id': 'Saint-Henri'}
# {'total': 99, '_id': 'Columbus'}
# {'total': 99, '_id': 'Chateauguay'}
# {'total': 96, '_id': 'North Toronto'}
# {'total': 96, '_id': 'St-Jerome'}
# {'total': 96, '_id': 'Montréal-Nord'}
# {'total': 96, '_id': 'Wildwood'}
# {'total': 93, '_id': 'Mont-Saint-Grégoire'}
# {'total': 93, '_id': 'Mount Albert'}
# {'total': 90, '_id': 'Kennedy Township'}
# {'total': 90, '_id': 'MONROEVILLE'}
# {'total': 90, '_id': 'Shaler Township'}
# {'total': 90, '_id': 'Goodwood'}
# {'total': 87, '_id': 'INDIAN LAND'}
# {'total': 87, '_id': 'Downsview'}
# {'total': 87, '_id': 'East Cleveland'}
# {'total': 87, '_id': 'Philo'}
# {'total': 87, '_id': 'Richmonhill'}
# {'total': 87, '_id': "L'ile-Perrot"}
# {'total': 87, '_id': 'Morgan Hill'}
# {'total': 87, '_id': 'Bellvue'}
# {'total': 87, '_id': 'Mascouche'}
# {'total': 84, '_id': 'Montrèal'}
# {'total': 84, '_id': 'Shorewood Hills'}
# {'total': 84, '_id': 'Brunswick Hills'}
# {'total': 84, '_id': 'Richmond Hts'}
# {'total': 84, '_id': 'New Eagle'}
# {'total': 81, '_id': 'Montreal-West'}
# {'total': 81, '_id': 'Oka'}
# {'total': 81, '_id': 'Elrama'}
# {'total': 81, '_id': 'cave creek'}
# {'total': 81, '_id': 'East Pittsburgh'}
# {'total': 81, '_id': 'Cleveland Hghts.'}
# {'total': 81, '_id': 'St-Leonard'}
# {'total': 81, '_id': 'Sidney'}
# {'total': 78, '_id': 'Mcknight'}
# {'total': 78, '_id': 'Mount Washington'}
# {'total': 78, '_id': 'Edgewood'}
# {'total': 78, '_id': 'Concord Township'}
# {'total': 78, '_id': 'Bainbridge Township'}
# {'total': 78, '_id': 'Saint-Sauveur-des-Monts'}
# {'total': 78, '_id': 'Mayfield Heights (Cleveland)'}
# {'total': 78, '_id': 'Rosemere'}
# {'total': 78, '_id': 'Duquesne'}
# {'total': 78, '_id': 'Kahnawake'}
# {'total': 78, '_id': 'Belle Vernon'}
# {'total': 78, '_id': 'Boston Heights'}
# {'total': 75, '_id': 'Scarobrough'}
# {'total': 75, '_id': 'Central'}
# {'total': 75, '_id': 'Marshall'}
# {'total': 75, '_id': 'Mckeesport'}
# {'total': 75, '_id': 'Erie'}
# {'total': 75, '_id': 'Central City Village'}
# {'total': 75, '_id': 'Northwest Calgary'}
# {'total': 75, '_id': 'N. Olmsted'}
# {'total': 75, '_id': 'Monoroeville'}
# {'total': 75, '_id': 'Homer'}
# {'total': 72, '_id': 'Morin-Heights'}
# {'total': 72, '_id': 'New River'}
# {'total': 72, '_id': 'City Center'}
# {'total': 72, '_id': 'Joliette'}
# {'total': 72, '_id': 'Auburn Township'}
# {'total': 72, '_id': 'East Mc Keesport'}
# {'total': 69, '_id': 'Le Sud-Ouest'}
# {'total': 69, '_id': 'McKeesRocks'}
# {'total': 69, '_id': 'North of Brampton'}
# {'total': 69, '_id': 'Cote Saint-Luc'}
# {'total': 69, '_id': 'Downtown Toronto'}
# {'total': 69, '_id': 'Rocky View No. 44'}
# {'total': 69, '_id': 'Sainte-Genevieve'}
# {'total': 69, '_id': 'Oberlin'}
# {'total': 66, '_id': 'Rostraver'}
# {'total': 66, '_id': 'Phx'}
# {'total': 66, '_id': 'Mentor On the Lake'}
# {'total': 66, '_id': 'Promenade'}
# {'total': 66, '_id': 'FORT MILL'}
# {'total': 66, '_id': 'Cuyahoga Heights'}
# {'total': 66, '_id': 'Piedmont'}
# {'total': 66, '_id': 'Saint-Bruno-de-Montarville'}
# {'total': 66, '_id': "L'Île-Bizard"}
# {'total': 66, '_id': 'Thornhil'}
# {'total': 66, '_id': 'Perry'}
# {'total': 66, '_id': 'Bedford Hts'}
# {'total': 63, '_id': 'Queen creek'}
# {'total': 63, '_id': 'toronto'}
# {'total': 63, '_id': 'San Tan Valley'}
# {'total': 63, '_id': 'Montreal-Ouest'}
# {'total': 63, '_id': 'St-Bruno-de-Montarville'}
# {'total': 63, '_id': 'Durham Regional Municipality'}
# {'total': 63, '_id': 'Urbana, Illinois'}
# {'total': 63, '_id': 'Grand Canyon'}
# {'total': 63, '_id': 'Communauté-Urbaine-de-Montréal'}
# {'total': 63, '_id': 'North Huntington'}
# {'total': 63, '_id': 'Tottenham'}
# {'total': 63, '_id': 'N E Las Vegas'}
# {'total': 63, '_id': 'Pointe-Aux-Trembles'}
# {'total': 60, '_id': 'Clarkson'}
# {'total': 60, '_id': 'Lufkin'}
# {'total': 60, '_id': 'Ste-Rose'}
# {'total': 60, '_id': 'Venetia'}
# {'total': 60, '_id': 'LaGrange'}
# {'total': 60, '_id': 'CONCORD'}
# {'total': 60, '_id': 'Nellis Air Force Base'}
# {'total': 60, '_id': 'Geauga'}
# {'total': 57, '_id': 'Repentigny'}
# {'total': 57, '_id': 'East Mississauga'}
# {'total': 57, '_id': 'Novelty'}
# {'total': 57, '_id': 'Beeton'}
# {'total': 57, '_id': 'moon'}
# {'total': 57, '_id': '\u200bChandler'}
# {'total': 54, '_id': "Notre-Dame-de-l'Ile-Perrot"}
# {'total': 54, '_id': 'Whiitby'}
# {'total': 54, '_id': 'Troy Township'}
# {'total': 54, '_id': 'Saint-Bruno'}
# {'total': 54, '_id': 'TORONTO'}
# {'total': 54, '_id': 'Lakewood, Oh'}
# {'total': 54, '_id': 'Scottsdale, AZ'}
# {'total': 54, '_id': 'Estérel'}
# {'total': 54, '_id': 'Franklin Park'}
# {'total': 54, '_id': 'Shaker Hts'}
# {'total': 54, '_id': 'Creighton'}
# {'total': 51, '_id': 'Moon TWP'}
# {'total': 51, '_id': 'Hendersonville'}
# {'total': 51, '_id': 'Fort mill'}
# {'total': 51, '_id': 'Ahwahtukee'}
# {'total': 51, '_id': 'Temecula'}
# {'total': 51, '_id': 'Sainte-Catherine'}
# {'total': 51, '_id': 'Pointe Claire'}
# {'total': 51, '_id': 'Holland Landing'}
# {'total': 51, '_id': 'Warrensville Hts'}
# {'total': 51, '_id': 'Pine'}
# {'total': 51, '_id': 'Cleveland Heigh'}
# {'total': 51, '_id': 'Bratenahl'}
# {'total': 51, '_id': 'Warrensville'}
# {'total': 51, '_id': 'Glen Williams'}
# {'total': 51, '_id': 'Mt Holly'}
# {'total': 51, '_id': 'New York'}
# {'total': 51, '_id': 'Ballantyne'}
# {'total': 51, '_id': 'University Ht'}
# {'total': 51, '_id': 'University Hts '}
# {'total': 48, '_id': 'Chargrin Falls'}
# {'total': 48, '_id': 'Brooklyn Heights'}
# {'total': 48, '_id': 'Highland Hills'}
# {'total': 48, '_id': 'Rural Ridge'}
# {'total': 48, '_id': 'Northfield Center Township'}
# {'total': 48, '_id': 'Cuddy'}
# {'total': 48, '_id': 'Lawrence'}
# {'total': 48, '_id': 'Moon Twp'}
# {'total': 48, '_id': 'Barberton'}
# {'total': 48, '_id': 'Nellis Afb'}
# {'total': 48, '_id': 'Mesa AZ'}
# {'total': 45, '_id': 'MACEDONIA'}
# {'total': 45, '_id': 'Red Mountain'}
# {'total': 45, '_id': 'tempe'}
# {'total': 45, '_id': 'East Mesa'}
# {'total': 45, '_id': 'Sainte-Anne-des-Plaines'}
# {'total': 45, '_id': 'Rawdon'}
# {'total': 45, '_id': 'AVON'}
# {'total': 45, '_id': 'Las Vegas Nv'}
# {'total': 45, '_id': 'GASTONIA'}
# {'total': 45, '_id': 'Pitcairn'}
# {'total': 45, '_id': 'Median'}
# {'total': 45, '_id': 'Saint Laurent'}
# {'total': 45, '_id': 'Ashburn'}
# {'total': 45, '_id': 'Las Vegas, NV'}
# {'total': 45, '_id': 'Saint-Philippe'}
# {'total': 45, '_id': 'Mathews'}
# {'total': 45, '_id': 'Saint-Marc-sur-Richelieu'}
# {'total': 42, '_id': 'Hyland Heights'}
# {'total': 42, '_id': 'Cooksville'}
# {'total': 42, '_id': 'Eighty Four'}
# {'total': 42, '_id': 'Etobiicoke'}
# {'total': 42, '_id': 'North Strabane Township'}
# {'total': 42, '_id': 'North Charlotte'}
# {'total': 42, '_id': 'Harrisburg,'}
# {'total': 42, '_id': 'Yorkville'}
# {'total': 42, '_id': 'Phoenix '}
# {'total': 42, '_id': 'Mt. Holly'}
# {'total': 42, '_id': 'River Drive Park'}
# {'total': 42, '_id': 'Phoenx'}
# {'total': 42, '_id': 'Russell Twp'}
# {'total': 39, '_id': 'Arrowhead'}
# {'total': 39, '_id': 'Sunnyslope'}
# {'total': 39, '_id': 'Ville Mont-Royal'}
# {'total': 39, '_id': 'St Leonard'}
# {'total': 39, '_id': 'Marvin'}
# {'total': 39, '_id': 'Cranberry Twp'}
# {'total': 39, '_id': 'Thorncliffe Park'}
# {'total': 39, '_id': 'Mercier'}
# {'total': 39, '_id': 'Salaberry-De-Valleyfield'}
# {'total': 39, '_id': 'Hendserson'}
# {'total': 39, '_id': 'surprise'}
# {'total': 39, '_id': 'North Scottsdale'}
# {'total': 39, '_id': 'South Amherst'}
# {'total': 39, '_id': 'Middleburg Hts.'}
# {'total': 39, '_id': 'Deerfield'}
# {'total': 36, '_id': 'Roxboro'}
# {'total': 36, '_id': 'Fabreville'}
# {'total': 36, '_id': 'N. Randall'}
# {'total': 36, '_id': 'Cuyahoga Fls'}
# {'total': 36, '_id': 'Rillton'}
# {'total': 36, '_id': 'Clinton'}
# {'total': 36, '_id': 'South Hills'}
# {'total': 36, '_id': 'Oak Ridges'}
# {'total': 36, '_id': 'glendale'}
# {'total': 36, '_id': 'Salaberry-de-Valleyfield'}
# {'total': 36, '_id': 'Phoenix,'}
# {'total': 36, '_id': 'Montgomery'}
# {'total': 36, '_id': 'Black Rock City'}
# {'total': 36, '_id': 'Mt. Horeb'}
# {'total': 36, '_id': 'PARMA HEIGHTS'}
# {'total': 33, '_id': 'Ross'}
# {'total': 33, '_id': 'Central City'}
# {'total': 33, '_id': 'Scottadale'}
# {'total': 33, '_id': 'Summerlin South'}
# {'total': 33, '_id': 'Los Angeles'}
# {'total': 33, '_id': 'Indianola'}
# {'total': 33, '_id': 'Ahwatukee Foothills Village'}
# {'total': 33, '_id': 'Northfield Center'}
# {'total': 33, '_id': 'Ft. Mill'}
# {'total': 33, '_id': 'Saint-Jean-Sur-Richelieu'}
# {'total': 33, '_id': 'Antioch'}
# {'total': 33, '_id': 'Pincourt'}
# {'total': 33, '_id': 'Southeast Calgary'}
# {'total': 33, '_id': 'Pittsburgh '}
# {'total': 33, '_id': 'Saint-Hippolyte'}
# {'total': 33, '_id': 'Mississuaga'}
# {'total': 33, '_id': 'Québec'}
# {'total': 33, '_id': 'Ville Saint Laurent'}
# {'total': 30, '_id': 'Rankin'}
# {'total': 30, '_id': 'Auburn Twp'}
# {'total': 30, '_id': 'Côte Saint-Luc'}
# {'total': 30, '_id': 'Berry'}
# {'total': 30, '_id': 'East Calgary'}
# {'total': 30, '_id': 'Lake Norman'}
# {'total': 30, '_id': 'North  York'}
# {'total': 30, '_id': 'Rockyview'}
# {'total': 30, '_id': 'Inglewood'}
# {'total': 30, '_id': 'Malton'}
# {'total': 30, '_id': 'Phoeniix'}
# {'total': 30, '_id': 'Candiac'}
# {'total': 30, '_id': 'Huntington Beach'}
# {'total': 30, '_id': 'Chandler-Gilbert'}
# {'total': 30, '_id': 'Silver Lake'}
# {'total': 30, '_id': 'Canonsburd'}
# {'total': 30, '_id': 'Division No. 6'}
# {'total': 27, '_id': 'Harwick'}
# {'total': 27, '_id': 'Gifford'}
# {'total': 27, '_id': 'Lynhurst'}
# {'total': 27, '_id': 'Ansnorveldt'}
# {'total': 27, '_id': 'Fisher'}
# {'total': 27, '_id': 'Farmington'}
# {'total': 27, '_id': 'Noyan'}
# {'total': 27, '_id': 'S Concord'}
# {'total': 27, '_id': 'Sainte-Therese'}
# {'total': 27, '_id': 'N. Ridgeville'}
# {'total': 27, '_id': 'Tolono'}
# {'total': 27, '_id': 'Char'}
# {'total': 27, '_id': 'Ingram'}
# {'total': 27, '_id': 'Hampstead'}
# {'total': 27, '_id': 'verdun'}
# {'total': 27, '_id': 'Moseley'}
# {'total': 27, '_id': 'Wellington'}
# {'total': 27, '_id': 'Brooklyn Hts.'}
# {'total': 27, '_id': 'Weston'}
# {'total': 27, '_id': 'Valleywide'}
# {'total': 27, '_id': 'Vaudreuil'}
# {'total': 27, '_id': 'GLENDALE'}
# {'total': 27, '_id': 'Côte-Saint-Luc'}
# {'total': 27, '_id': 'Bois-des-Filion'}
# {'total': 27, '_id': 'Monreoville'}
# {'total': 27, '_id': 'Sainte-Thérèse-de-Blainville'}
# {'total': 24, '_id': 'springdale'}
# {'total': 24, '_id': 'Montréal-West'}
# {'total': 24, '_id': 'Tucson'}
# {'total': 24, '_id': 'Union'}
# {'total': 24, '_id': 'Reminderville'}
# {'total': 24, '_id': 'Mooers'}
# {'total': 24, '_id': 'SW Calgary'}
# {'total': 24, '_id': 'SCARBOROUGH'}
# {'total': 24, '_id': 'Val-Morin'}
# {'total': 24, '_id': 'North Carolina'}
# {'total': 24, '_id': 'CLEVELAND'}
# {'total': 24, '_id': 'ETOBICOKE'}
# {'total': 24, '_id': 'Pointe-Calumet'}
# {'total': 24, '_id': 'solon'}
# {'total': 24, '_id': 'Huntsburg'}
# {'total': 24, '_id': 'Omaha'}
# {'total': 24, '_id': 'Mayfield Heights.'}
# {'total': 24, '_id': 'Las Vegass'}
# {'total': 24, '_id': 'North Las Vegas '}
# {'total': 24, '_id': 'Leeds'}
# {'total': 24, '_id': 'West Toronto'}
# {'total': 24, '_id': 'Nevada'}
# {'total': 24, '_id': 'McMurry'}
# {'total': 24, '_id': 'Surprise Crossing'}
# {'total': 24, '_id': 'Napierville'}
# {'total': 24, '_id': 'Old Town Scottsdale'}
# {'total': 21, '_id': 'Spartanburg'}
# {'total': 21, '_id': 'Valencia'}
# {'total': 21, '_id': 'Buena Vista'}
# {'total': 21, '_id': 'Mccandless Township'}
# {'total': 21, '_id': 'Westview'}
# {'total': 21, '_id': 'Old Brooklyn'}
# {'total': 21, '_id': 'Henderson and Las vegas'}
# {'total': 21, '_id': 'Mayfield Hts'}
# {'total': 21, '_id': 'AGINCOURT'}
# {'total': 21, '_id': 'St.Pittsburgh'}
# {'total': 21, '_id': 'Hemmingford'}
# {'total': 21, '_id': 'Avon lake'}
# {'total': 21, '_id': 'Coteau-du-Lac'}
# {'total': 21, '_id': 'Pepperpike'}
# {'total': 21, '_id': 'NEWMARKET'}
# {'total': 21, '_id': 'Decatur'}
# {'total': 21, '_id': 'Cote-Saint-Luc'}
# {'total': 21, '_id': 'Buckeye - Shaker'}
# {'total': 21, '_id': 'The Promenade'}
# {'total': 21, '_id': 'Plum Boro'}
# {'total': 21, '_id': 'Peninsul'}
# {'total': 21, '_id': 'Saint-Charles-Borromee'}
# {'total': 21, '_id': 'Lachenaie'}
# {'total': 21, '_id': 'La Vegas'}
# {'total': 21, '_id': 'Prévost'}
# {'total': 21, '_id': 'Ingomar'}
# {'total': 21, '_id': 'Garfield Hts'}
# {'total': 21, '_id': 'Mount Oliver'}
# {'total': 21, '_id': 'Norval'}
# {'total': 21, '_id': 'Sturgeon'}
# {'total': 18, '_id': 'Westworld Scottsdale'}
# {'total': 18, '_id': 'Chander'}
# {'total': 18, '_id': 'Broadlands'}
# {'total': 18, '_id': 'Huntingdon'}
# {'total': 18, '_id': 'Saintt-Bruno-de-Montarville'}
# {'total': 18, '_id': 'Beauharnois'}
# {'total': 18, '_id': 'San Tan'}
# {'total': 18, '_id': 'Shady Side'}
# {'total': 18, '_id': 'Quartier des Spectacles'}
# {'total': 18, '_id': 'Whtiby'}
# {'total': 18, '_id': 'North Braddock'}
# {'total': 18, '_id': 'Phoenix AZ'}
# {'total': 18, '_id': 'Sutersville'}
# {'total': 18, '_id': 'DENVER'}
# {'total': 18, '_id': 'CAVE CREEK'}
# {'total': 18, '_id': 'Montréal (Québec)'}
# {'total': 18, '_id': 'Warrendale'}
# {'total': 18, '_id': 'Charlemagne'}
# {'total': 18, '_id': 'Farnham'}
# {'total': 18, '_id': 'markham'}
# {'total': 18, '_id': 'Markham, ON'}
# {'total': 18, '_id': 'Litchfield park'}
# {'total': 18, '_id': 'Villa Grove'}
# {'total': 18, '_id': 'Chatauguay'}
# {'total': 18, '_id': 'Saint - Hyacinthe'}
# {'total': 18, '_id': 'THORNHILL'}
# {'total': 18, '_id': "L'ile-Bizard"}
# {'total': 18, '_id': 'Allegheny'}
# {'total': 18, '_id': 'Sunrise Manor'}
# {'total': 18, '_id': 'Kettleby'}
# {'total': 18, '_id': 'West Elizabeth'}
# {'total': 18, '_id': 'Lodi'}
# {'total': 18, '_id': 'NORTH YORK'}
# {'total': 18, '_id': 'Greenway'}
# {'total': 18, '_id': 'Woodbridge (Vaughan)'}
# {'total': 18, '_id': 'Zephyr'}
# {'total': 18, '_id': 'Cleveland, OH'}
# {'total': 18, '_id': 'Old Scottsdale'}
# {'total': 18, '_id': 'Deux-Montagnes Regional County Municipality'}
# {'total': 15, '_id': 'Henderson Nevada'}
# {'total': 15, '_id': "L'assomption"}
# {'total': 15, '_id': 'Sainte-Marthe'}
# {'total': 15, '_id': 'Whitney'}
# {'total': 15, '_id': 'Crescent'}
# {'total': 15, '_id': 'Chertsey'}
# {'total': 15, '_id': 'Rougemont'}
# {'total': 15, '_id': 'Rocky river'}
# {'total': 15, '_id': 'Cave Creek Road'}
# {'total': 15, '_id': 'Southside Flats'}
# {'total': 15, '_id': 'Beltline'}
# {'total': 15, '_id': 'Saint-Basile-Le-Grand'}
# {'total': 15, '_id': 'Leaside'}
# {'total': 15, '_id': 'Lake Las Vegas'}
# {'total': 15, '_id': 'East Gwilimbury'}
# {'total': 15, '_id': 'East Credit'}
# {'total': 15, '_id': 'St. Jean Sur Richelieu'}
# {'total': 15, '_id': 'Montville'}
# {'total': 15, '_id': 'Lindale'}
# {'total': 15, '_id': "De l'Eglise"}
# {'total': 15, '_id': 'Sage Hill'}
# {'total': 15, '_id': 'Mentor-On-The-Lake'}
# {'total': 15, '_id': 'Mesa Arizona'}
# {'total': 15, '_id': "Notre-Dame-De-L'ile-Perrot"}
# {'total': 15, '_id': 'Strip District'}
# {'total': 15, '_id': 'Bakerstown'}
# {'total': 15, '_id': 'Alburg'}
# {'total': 15, '_id': 'Fox Chapel'}
# {'total': 15, '_id': 'Northyork'}
# {'total': 15, '_id': 'Side Slopes'}
# {'total': 15, '_id': 'Agincourt'}
# {'total': 15, '_id': 'Otterburn Park'}
# {'total': 15, '_id': 'Île-des-Soeurs'}
# {'total': 15, '_id': 'Estrella Village'}
# {'total': 12, '_id': 'Saint-Isidore-de-Laprairie'}
# {'total': 12, '_id': 'Dublin'}
# {'total': 12, '_id': 'Mayfield Hts.'}
# {'total': 12, '_id': 'Glbert'}
# {'total': 12, '_id': 'south Euclid'}
# {'total': 12, '_id': 'Pheonix'}
# {'total': 12, '_id': 'Oakridges'}
# {'total': 12, '_id': 'Murrysville (Monroeville)'}
# {'total': 12, '_id': 'Sainte-Madeleine'}
# {'total': 12, '_id': 'Mississauaga'}
# {'total': 12, '_id': 'Centre Island'}
# {'total': 12, '_id': 'Nottingham Township'}
# {'total': 12, '_id': 'Nationwide'}
# {'total': 12, '_id': 'South Russell'}
# {'total': 12, '_id': 'Sainte-Marguerite-du-Lac-Masson'}
# {'total': 12, '_id': 'Saint-Bernard de Lacolle'}
# {'total': 12, '_id': 'Painesville Township'}
# {'total': 12, '_id': 'Claremont'}
# {'total': 12, '_id': 'Toronto-North York'}
# {'total': 12, '_id': 'Joliet'}
# {'total': 12, '_id': 'calgary'}
# {'total': 12, '_id': 'Phoniex'}
# {'total': 12, '_id': 'Pittsburch'}
# {'total': 12, '_id': 'Etobicoke,'}
# {'total': 12, '_id': 'QUEEN CREEK'}
# {'total': 12, '_id': 'Toronto Scarborough'}
# {'total': 12, '_id': 'Highland Hts'}
# {'total': 12, '_id': 'Palgrave'}
# {'total': 12, '_id': 'Bentleyville'}
# {'total': 12, '_id': 'Harmar Township'}
# {'total': 12, '_id': 'Mc Adenville'}
# {'total': 12, '_id': 'Rainbow Valley'}
# {'total': 12, '_id': 'Arizona'}
# {'total': 12, '_id': 'Venise-en-Québec'}
# {'total': 12, '_id': 'Stetson Valley'}
# {'total': 12, '_id': 'Point-Claire'}
# {'total': 12, '_id': 'St. Leonard'}
# {'total': 12, '_id': 'Down'}
# {'total': 12, '_id': 'Penn Hills Township'}
# {'total': 12, '_id': 'North Olmsted,'}
# {'total': 12, '_id': 'Milford'}
# {'total': 12, '_id': 'Sainte-Marguerite-du-lac-Masson'}
# {'total': 12, '_id': 'Monterey Park'}
# {'total': 12, '_id': 'Highland Park'}
# {'total': 12, '_id': 'Central Oakland'}
# {'total': 12, '_id': 'Dewey'}
# {'total': 12, '_id': 'North  Ridgeville'}
# {'total': 12, '_id': 'McKnight'}
# {'total': 12, '_id': 'Darlington'}
# {'total': 12, '_id': 'Saint Leonard'}
# {'total': 12, '_id': 'Cave creek'}
# {'total': 12, '_id': 'Draper'}
# {'total': 12, '_id': 'Newburgh Heights'}
# {'total': 12, '_id': 'Pasadena'}
# {'total': 12, '_id': "L'Assomption"}
# {'total': 12, '_id': 'Phoneix'}
# {'total': 12, '_id': 'Greensboro'}
# {'total': 12, '_id': 'Frazer'}
# {'total': 12, '_id': 'charlottte'}
# {'total': 12, '_id': 'Varennes'}
# {'total': 12, '_id': 'Sandy Ridge'}
# {'total': 12, '_id': 'Fithian'}
# {'total': 12, '_id': 'MATTHEWS'}
# {'total': 12, '_id': 'Saint-Pierre-de-Véronne-à-Pike-River'}
# {'total': 12, '_id': 'Yorkdale'}
# {'total': 12, '_id': 'montreal'}
# {'total': 12, '_id': 'Iberville'}
# {'total': 12, '_id': 'Paw Creek'}
# {'total': 12, '_id': 'Phoenix Valley'}
# {'total': 12, '_id': 'Richland Township'}
# {'total': 12, '_id': 'Mcdonald'}
# {'total': 12, '_id': 'Sainte-Marguerite-Esterel'}
# {'total': 12, '_id': 'Sale'}
# {'total': 12, '_id': 'Metro Phoenix'}
# {'total': 12, '_id': 'Closter'}
# {'total': 12, '_id': 'Mt. Washington'}
# {'total': 12, '_id': 'De Winton'}
# {'total': 12, '_id': 'Scotesdale'}
# {'total': 12, '_id': 'Snowflake'}
# {'total': 12, '_id': 'Auburn'}
# {'total': 12, '_id': 'Moon Twp.'}
# {'total': 9, '_id': 'Boston'}
# {'total': 9, '_id': 'Bloomfield'}
# {'total': 9, '_id': 'Midway'}
# {'total': 9, '_id': 'Ste-Dorothée'}
# {'total': 9, '_id': 'London'}
# {'total': 9, '_id': 'Austin'}
# {'total': 9, '_id': 'Toronto-West'}
# {'total': 9, '_id': 'St. Léonard'}
# {'total': 9, '_id': 'Lancaster'}
# {'total': 9, '_id': 'Ste-Therese-de-Blainville'}
# {'total': 9, '_id': 'Aliquippa'}
# {'total': 9, '_id': 'Deux-Montagnes'}
# {'total': 9, '_id': 'Lake Park'}
# {'total': 9, '_id': 'Lavaltrie'}
# {'total': 9, '_id': 'Streetsville'}
# {'total': 9, '_id': 'Oldham'}
# {'total': 9, '_id': 'Mansfield'}
# {'total': 9, '_id': "Baie-d'Urfé"}
# {'total': 9, '_id': 'New Glarus'}
# {'total': 9, '_id': 'Chattanooga'}
# {'total': 9, '_id': 'Scotsdale'}
# {'total': 9, '_id': 'Northeast Calgary'}
# {'total': 9, '_id': 'Ormstown'}
# {'total': 9, '_id': 'Port Vue'}
# {'total': 9, '_id': 'Citibank'}
# {'total': 9, '_id': 'peoria'}
# {'total': 9, '_id': 'N Solon'}
# {'total': 9, '_id': "O'hara Township"}
# {'total': 9, '_id': 'Montréal-Est'}
# {'total': 9, '_id': 'Scarbrough'}
# {'total': 9, '_id': 'Maricopa'}
# {'total': 9, '_id': 'Mississagua'}
# {'total': 9, '_id': 'Perry Twp'}
# {'total': 9, '_id': 'Vaughan Mills'}
# {'total': 9, '_id': 'Garrettsville'}
# {'total': 9, '_id': 'Medicine Hat'}
# {'total': 9, '_id': 'Laval, Pont Viau'}
# {'total': 9, '_id': 'Red Rock'}
# {'total': 9, '_id': 'Suncity'}
# {'total': 9, '_id': 'NorthYork'}
# {'total': 9, '_id': 'Alburgh'}
# {'total': 9, '_id': 'Crouse'}
# {'total': 9, '_id': 'Seattle'}
# {'total': 9, '_id': 'Los Vegas'}
# {'total': 9, '_id': 'Les Cèdres'}
# {'total': 9, '_id': 'Laval, Ste Dorothee'}
# {'total': 9, '_id': 'Apache Trail'}
# {'total': 9, '_id': 'Pickering Ajax Whitby'}
# {'total': 9, '_id': 'Uptown'}
# {'total': 9, '_id': 'Sun CIty'}
# {'total': 9, '_id': 'Lake Mead'}
# {'total': 9, '_id': 'Cleveland Hts.'}
# {'total': 9, '_id': 'Godmanchester'}
# {'total': 9, '_id': 'Las Vegas Nevada'}
# {'total': 9, '_id': 'SUN PRAIRIE'}
# {'total': 9, '_id': 'St-Lazare'}
# {'total': 9, '_id': 'Ivesdale'}
# {'total': 9, '_id': 'CALGARY'}
# {'total': 9, '_id': 'Las Vegas Valley'}
# {'total': 9, '_id': "Saint-Roch-de-l'Achigan"}
# {'total': 9, '_id': 'Hnederson'}
# {'total': 9, '_id': 'Las Vegas NV'}
# {'total': 9, '_id': 'Vieux-Montréal'}
# {'total': 9, '_id': 'Tempe '}
# {'total': 9, '_id': 'Middleburg'}
# {'total': 9, '_id': 'oakville'}
# {'total': 9, '_id': 'Les Coteaux'}
# {'total': 9, '_id': 'Maple Grove'}
# {'total': 9, '_id': 'Old Port of Montreal'}
# {'total': 9, '_id': 'Indian Land,'}
# {'total': 9, '_id': 'Queensville'}
# {'total': 9, '_id': ''}
# {'total': 9, '_id': 'Cranberry Township'}
# {'total': 9, '_id': 'St. Joseph'}
# {'total': 9, '_id': 'AZ'}
# {'total': 9, '_id': 'Henryville'}
# {'total': 9, '_id': 'St-Jean-sur-Richelieu'}
# {'total': 9, '_id': 'Hamilton'}
# {'total': 9, '_id': 'Toronto-Etobicoke'}
# {'total': 9, '_id': 'Edgemont'}
# {'total': 9, '_id': 'Bond Head'}
# {'total': 9, '_id': 'Concord Twp'}
# {'total': 9, '_id': 'Edmonton'}
# {'total': 9, '_id': 'Cleveland Height'}
# {'total': 9, '_id': 'Vaughn'}
# {'total': 9, '_id': 'East Hawkesbury'}
# {'total': 9, '_id': 'CARSON'}
# {'total': 9, '_id': 'Thomasboro'}
# {'total': 9, '_id': 'Saint-Basile-le-Grand'}
# {'total': 9, '_id': 'Richmond Height'}
# {'total': 9, '_id': 'Le Haut-Saint-Laurent Regional County Municipality'}
# {'total': 9, '_id': 'Sharon'}
# {'total': 9, '_id': 'McMasterville'}
# {'total': 9, '_id': 'las Vegas'}
# {'total': 9, '_id': 'St-Clet'}
# {'total': 9, '_id': 'Somerton'}
# {'total': 9, '_id': 'Sacramento'}
# {'total': 9, '_id': 'Morgan'}
# {'total': 9, '_id': 'Montreal-Est'}
# {'total': 9, '_id': 'Sun Praiie'}
# {'total': 9, '_id': 'Ange-Gardien'}
# {'total': 9, '_id': 'Rockyview County'}
# {'total': 9, '_id': 'Cote Saint Luc'}
# {'total': 9, '_id': 'CAREFREE'}
# {'total': 9, '_id': 'Scottsale'}
# {'total': 9, '_id': 'etobicoke'}
# {'total': 9, '_id': 'Warrenville'}
# {'total': 9, '_id': 'Evergreen'}
# {'total': 9, '_id': 'Fountain Hls'}
# {'total': 9, '_id': 'Pgh Int Arprt'}
# {'total': 9, '_id': 'Cuyohoga Falls'}
# {'total': 9, '_id': 'West Lake'}
# {'total': 9, '_id': 'Church Cove'}
# {'total': 9, '_id': 'Lacolle'}
# {'total': 9, '_id': 'Phoenix Metro Area'}
# {'total': 9, '_id': 'Manchester'}
# {'total': 9, '_id': 'Saint-laurent'}
# {'total': 9, '_id': 'Rockey View'}
# {'total': 9, '_id': 'Brownsburg-Chatham'}
# {'total': 9, '_id': 'Mississaugua'}
# {'total': 9, '_id': 'Oakwood village'}
# {'total': 9, '_id': 'North york'}
# {'total': 9, '_id': 'Las Vergas'}
# {'total': 9, '_id': 'Sainte-thérèse'}
# {'total': 9, '_id': 'Twinsburgh'}
# {'total': 9, '_id': 'St. Sauveur'}
# {'total': 9, '_id': 'Columbia Sta'}
# {'total': 9, '_id': 'North Phoenix'}
# {'total': 9, '_id': 'Bury'}
# {'total': 9, '_id': 'Belœil'}
# {'total': 9, '_id': 'Chateau'}
# {'total': 9, '_id': 'TOLLESON'}

# %% [markdown]
# Join name of entities to tip to find out the name of the place receiving the most tips

# %%
# aggregate tips
group_query = [{
    '$group'  :{
        '_id': '$business_id',
        'compliment_total': {'$sum': '$compliment_count'}
    }},{
    '$out': 'tip_aggregate_by_business'}]

group_result = mydb['tip'].aggregate(group_query)

# %%
# select name and business_id from business
group_query = [{
    '$project':{
        'business_id':1,
        'name':1
    }},
    {
        '$group': {
            '_id': '$business_id',
            'business_name': {'$first':'$name'}
        }
    },
    {'$out': 'business_name'}]

group_result = mydb['business'].aggregate(group_query)

# %%
# join and sort
join_query = [
{
    '$lookup':{
        'from': 'business_name',
        'localField': '_id',
        'foreignField': '_id',
        'as': 'business_info'
    }}
    ,{
    '$project': {
        'compliment_total':1,
        'business_info.business_name':1,
        '_id':1
    }}
    ,
    {
    '$sort':{'compliment_total':-1}
    },
    {
    '$limit':10
    }
]

join_result = mydb['tip_aggregate_by_business'].aggregate(join_query)

# %%
for res in join_result:
    pprint.pprint(res)
# Out:
# {'_id': 'BQqwIYQuo2W94smjrBjy5g',
#  'business_info': [{'business_name': 'Il Chianti Italian Steak & Seafood'}],
#  'compliment_total': 204}
# {'_id': 'FaHADZARwnY4yvlvpnsfGA',
#  'business_info': [{'business_name': 'McCarran International Airport'}],
#  'compliment_total': 162}
# {'_id': 'RESDUcs7fIiihp38-d6_6g',
#  'business_info': [{'business_name': 'Bacchanal Buffet'}],
#  'compliment_total': 150}
# {'_id': '55E0-qUHa7Kzqz8rOhbdBQ',
#  'business_info': [{'business_name': 'Costco Gasoline'}],
#  'compliment_total': 120}
# {'_id': 'MpmFFw0GE_2iRFPdsRpJbA',
#  'business_info': [{'business_name': 'XS Nightclub'}],
#  'compliment_total': 111}
# {'_id': 'JmI9nslLD7KZqRr__Bg6NQ',
#  'business_info': [{'business_name': 'Phoenix Sky Harbor International '
#                                      'Airport'}],
#  'compliment_total': 105}
# {'_id': 'DN0b4Un8--Uf6SEWLeh0UA',
#  'business_info': [{'business_name': "Amy's Baking Company"}],
#  'compliment_total': 102}
# {'_id': 'QsKhwKYB3YeWXqpIPd5QMg',
#  'business_info': [{'business_name': 'Sonoma Cellar'}],
#  'compliment_total': 93}
# {'_id': 'QhXBIQWUmQxuVErdwY2QVw',
#  'business_info': [{'business_name': 'Manila BBQ'}],
#  'compliment_total': 93}
# {'_id': 'OMRYQihVjqqzjoNoQgyhgQ',
#  'business_info': [{'business_name': "Sister's Oriental Market & Video"}],
#  'compliment_total': 87}
